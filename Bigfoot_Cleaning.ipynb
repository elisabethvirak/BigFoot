# %% [markdown]
# # Bigfoot Data Cleaning
# ### The purpose of this notebook is to clean and compare three sets of Bigfoot siting reports, so that the data is free of redundancy, easy to follow, and usable for visualizations.

# %%
#Import libraries 

import pandas as pd
from sqlalchemy import create_engine
import json

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %%
#Store Data in Dataframe

csv_loc = "Resources/bfro_report_locations.csv"
csv_geo = "Resources/bfro_reports_geocoded.csv"
json_file = "Resources/bfro_reports.json"

bigfoot_locations_df = pd.read_csv(csv_loc)
bigfoot_geo_df = pd.read_csv(csv_geo)
bfro_rep_df = pd.read_json(json_file, lines=True)

# %% [markdown]
# ### Cleaning of bfro_report_locations

# %%
# Display location CSV DataFrame
bigfoot_locations_df.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
# Begin filtering data
# Drop null values on 'number'
bf_loc_transformed = bigfoot_locations_df[bigfoot_locations_df['number'].notna()]

# Split timestamp column into date and time column
bf_loc_transformed[['Date_loc','Time']] = bf_loc_transformed.timestamp.str.split("T",expand=True)

bf_loc_transformed.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude    Date_loc       Time
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000  2000-06-16  12:00:00Z
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982  1995-05-15  12:00:00Z
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202  2004-02-09  12:00:00Z
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667  2004-06-18  12:00:00Z
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853  2004-02-15  12:00:00Z

# %%
# Remove report number from title
bf_loc_transformed[['Report', 'Title']] = bf_loc_transformed.title.str.split(":",1,expand=True)
bf_loc_transformed.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude    Date_loc       Time  \
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000  2000-06-16  12:00:00Z
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982  1995-05-15  12:00:00Z
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202  2004-02-09  12:00:00Z
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667  2004-06-18  12:00:00Z
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853  2004-02-15  12:00:00Z
#
#          Report                                              Title
# 0    Report 637   Campers' encounter just after dark in the Wra...
# 1   Report 2917               Family observes large biped from car
# 2   Report 7963      Sasquatch walks past window of house at night
# 3   Report 9317   Driver on Alcan Highway has noon, road encoun...
# 4  Report 13038   Snowmobiler has encounter in deep snow near P...

# %%
# remove unwanted columns
# the time column does not provide beneficial data (all reports were at 12:00:00Z)
bf_loc_transformed = bf_loc_transformed[['number', 'classification', 'latitude', 'longitude', 'Date_loc', 'Title']]
bf_loc_transformed.head()
# Out:
#    number classification  latitude  longitude    Date_loc  \
# 0     637        Class A   61.5000  -142.9000  2000-06-16
# 1    2917        Class A   55.1872  -132.7982  1995-05-15
# 2    7963        Class A   55.2035  -132.8202  2004-02-09
# 3    9317        Class A   62.9375  -141.5667  2004-06-18
# 4   13038        Class A   61.0595  -149.7853  2004-02-15
#
#                                                Title
# 0   Campers' encounter just after dark in the Wra...
# 1               Family observes large biped from car
# 2      Sasquatch walks past window of house at night
# 3   Driver on Alcan Highway has noon, road encoun...
# 4   Snowmobiler has encounter in deep snow near P...

# %%
# sort reports by report number
bf_loc_transformed.sort_values(by=['number'], inplace=True)
bf_loc_transformed.reset_index(drop=True, inplace=True)
bf_loc_transformed
# Out:
#       number classification  latitude  longitude    Date_loc  \
# 0         60        Class B  48.64056 -121.80530  1994-05-13
# 1         76        Class B  36.37139  -92.25139  2001-08-11
# 2         77        Class B  46.98333 -121.09220  1983-09-01
# 3         80        Class B  43.69005 -122.37550  1983-08-12
# 4         83        Class A  37.35944 -119.64360  1988-10-01
# ...      ...            ...       ...        ...         ...
# 3989   62352        Class B  38.17600  -95.34650  2017-04-17
# 3990   62354        Class A  48.92982 -122.20180  2018-09-15
# 3991   62393        Class A  37.79250  -92.05000  2017-07-08
# 3992   62403        Class B  48.56245 -121.85880  2018-09-15
# 3993   62405        Class B  37.27400  -94.93115  1995-06-16
#
#                                                   Title
# 0             Missing Cattle and large footprints found
# 1      Three fisherman hear thrashing about and loud...
# 2      Couple hear vocalizations while camping at Mi...
# 3      Late Arriving Campers Hear Running, Stomping,...
# 4         Early dawn sighting by hunters near Bass Lake
# ...                                                 ...
# 3989   Group of fisherman with a possible sighting o...
# 3990   Son and father observe possible bigfoot famil...
# 3991   Ozarks: Daylight sighting on eastern boundary...
# 3992   Mushroom picker has ongoing activity in same ...
# 3993   Daylight encounter in a strip mine gully near...
#
# [3994 rows x 6 columns]

# %%
# double-check to see if any columns hold null values
bf_loc_transformed.count()
# Out:
# number            3994
# classification    3994
# latitude          3994
# longitude         3994
# Date_loc          3994
# Title             3994
# dtype: int64

# %% [markdown]
# ### Cleaning of bfro_reports_geocoded
# location_details, season, temperature_high, temperature_mid, temperature_low, dew_point, humidity, cloud_cover, moon_phase, precip_intensity, precip_probability, precip_type, pressure, summary, uv_index, visibility, wind_bearing, and wind_speed removed.
# More accurate information regarding weather will be pulled from OpenWeatherMap later.

# %%
bigfoot_geo_df.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# 4                     Ward County   North Dakota  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 55269: Dawn sighting at Stevens Brook o...  43.41549  -72.33093
# 3  Report 59757: Possible daylight sighting of a ...  42.15685  -96.34203
# 4  Report 751: Hunter describes described being s...  48.25422 -101.31660
#
#          date   number  ... moon_phase precip_intensity  precip_probability  \
# 0         NaN   1261.0  ...        NaN              NaN                 NaN
# 1         NaN    438.0  ...        NaN              NaN                 NaN
# 2  2016-06-07  55269.0  ...       0.10            0.001                 0.7
# 3  2018-05-25  59757.0  ...       0.38            0.000                 0.0
# 4  2000-04-21    751.0  ...       0.60              NaN                 NaN
#
#    precip_type  pressure                            summary  uv_index  \
# 0          NaN       NaN                                NaN       NaN
# 1          NaN       NaN                                NaN       NaN
# 2         rain    998.87  Mostly cloudy throughout the day.       6.0
# 3          NaN   1008.07      Partly cloudy in the morning.      10.0
# 4         rain   1011.47       Partly cloudy until evening.       6.0
#
#    visibility  wind_bearing  wind_speed
# 0         NaN           NaN         NaN
# 1         NaN           NaN         NaN
# 2        9.70         262.0        0.49
# 3        8.25         193.0        3.33
# 4       10.00         237.0       11.14
#
# [5 rows x 28 columns]

# %%
# Begin filtering data
bf_geo_cols = ['observed', 'county', 'state', 'latitude', 'longitude', 'date','number', 'classification', 'geohash']
bf_geo_transformed = bigfoot_geo_df[bf_geo_cols].copy()

# Drop null values on 'number'
bf_geo_transformed = bf_geo_transformed[bf_geo_transformed['number'].notna()]

bf_geo_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                            county          state  latitude  longitude  \
# 0  Valdez-Chitina-Whittier County         Alaska       NaN        NaN
# 1                   Warren County     New Jersey       NaN        NaN
# 2                 Sullivan County  New Hampshire  43.41549  -72.33093
# 3                 Thurston County       Nebraska  42.15685  -96.34203
# 4                     Ward County   North Dakota  48.25422 -101.31660
#
#          date   number classification     geohash
# 0         NaN   1261.0        Class A         NaN
# 1         NaN    438.0        Class B         NaN
# 2  2016-06-07  55269.0        Class A  drswfpd1x1
# 3  2018-05-25  59757.0        Class B  9z7rzdmv7y
# 4  2000-04-21    751.0        Class A  c8xfw2rt0n

# %%
# sort reports by report number
bf_geo_transformed.sort_values(by=['number'], inplace=True)
bf_geo_transformed.reset_index(drop=True, inplace=True)
bf_geo_transformed.head()
# Out:
#                                             observed             county  \
# 0  These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1  My wife and I were off the trail to take some ...  Washington County
# 2  I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3  We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4  My veterinarian sister, former girlfriend, and...        Lane County
#
#         state  latitude  longitude        date  number classification  \
# 0  Washington  48.64056 -121.80530  1994-05-13    60.0        Class B
# 1    New York       NaN        NaN         NaN    70.0        Class B
# 2    Arkansas  36.37139  -92.25139  2001-08-11    76.0        Class B
# 3  Washington  46.98333 -121.09220  1983-09-01    77.0        Class B
# 4      Oregon  43.69005 -122.37550  1983-08-12    80.0        Class B
#
#       geohash
# 0  c29ksq8pfc
# 1         NaN
# 2  9yqquv0wdy
# 3  c23gk3p3ep
# 4  9rbbx38bup

# %%
# double-check to make sure most necessary columns do not hold null values
# null values may be filled in merges
bf_geo_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# latitude          3797
# longitude         3797
# date              3797
# number            4747
# classification    4747
# geohash           3797
# dtype: int64

# %% [markdown]
# ### Cleaning of bfro_reports

# %%
bfro_rep_df.head()
# Out:
#            YEAR  SEASON          STATE                          COUNTY  \
# 0  Early 1990's    Fall         Alaska  Valdez-Chitina-Whittier County
# 1           NaN     NaN            NaN                             NaN
# 2          2000    Fall     New Jersey                   Warren County
# 3          2016  Summer  New Hampshire                 Sullivan County
# 4          2018  Spring       Nebraska                 Thurston County
#
#                                     LOCATION_DETAILS  \
# 0                  East side of Prince William Sound
# 1                                                NaN
# 2  the road is off us rt 80, i dont know the exit...
# 3  Close to Claremont down 120 not far from Kings...
# 4      Latitude & Longitude :  42.158230  -96.344197
#
#                                             OBSERVED  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1                                                NaN
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
#
#                                      OTHER_WITNESSES  \
# 0  On a commercial fishing boat at anchor at the ...
# 1                                                NaN
# 2  my friend was asleep, and i was lying next to ...
# 3                                        Just myself
# 4  2 witnesses saw the creature. 3 people were pr...
#
#                                  TIME_AND_CONDITIONS  REPORT_NUMBER  \
# 0                   Early Fall, in the early 1990's.         1261.0
# 1                                                NaN            NaN
# 2  lighting was from a camp fire that was dieing ...          438.0
# 3                           5am. Dawn. Clear weather        55269.0
# 4  1:35 pm on a clear and very hot sunny day. Tem...        59757.0
#
#   REPORT_CLASS      MONTH        DATE NEAREST_TOWN          NEAREST_ROAD  \
# 0      Class A        NaN         NaN          NaN                   NaN
# 1         None        NaN         NaN          NaN                   NaN
# 2      Class B  September  2nd or 3rd    Allumuchy  not sure of the road
# 3      Class A       June           7    Claremont               Rte 120
# 4      Class B        May          25         Macy           Highway 201
#
#                                         ALSO_NOTICED  \
# 0                                                NaN
# 1                                                NaN
# 2                                            nothing
# 3                                                NaN
# 4  I had audio recorders set up in the area and r...
#
#                                        OTHER_STORIES  \
# 0                                                NaN
# 1                                                NaN
# 2  no but after the events stated i looked at you...
# 3                                                NaN
# 4  There are MANY encounters in this general area...
#
#                                          ENVIRONMENT A_&_G_References
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  good size river, steep hills, very rugged area...              NaN
# 3  swamp with forest behind it. There was a large...              NaN
# 4  This is a heavily forested area bordering the ...              NaN

# %%
# Begin filtering json data
bf_reports_cols = ['OBSERVED', 'COUNTY', 'STATE', 'REPORT_NUMBER', 'REPORT_CLASS']
bf_reports_transformed = bfro_rep_df[bf_reports_cols].copy()

# Rename column headers
bf_reports_transformed = bf_reports_transformed.rename(columns={"OBSERVED": 'observed',
                                                               'COUNTY': 'county',
                                                               'STATE': 'state',
                                                               'REPORT_NUMBER': 'number',
                                                               'REPORT_CLASS': 'classification'})

# Drop null values on 'number'
bf_reports_transformed = bf_reports_transformed[bf_reports_transformed['number'].notna()]

bf_reports_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
# 5  While this incident occurred a long time ago, ...
#
#                            county          state   number classification
# 0  Valdez-Chitina-Whittier County         Alaska   1261.0        Class A
# 2                   Warren County     New Jersey    438.0        Class B
# 3                 Sullivan County  New Hampshire  55269.0        Class A
# 4                 Thurston County       Nebraska  59757.0        Class B
# 5                     Ward County   North Dakota    751.0        Class A

# %%
# sort reports by report number
bf_reports_transformed.sort_values(by=['number'], inplace=True)
bf_reports_transformed.reset_index(drop=True, inplace=True)
bf_reports_transformed.head()
# Out:
#                                             observed             county  \
# 0  These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1  My wife and I were off the trail to take some ...  Washington County
# 2  I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3  We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4  My veterinarian sister, former girlfriend, and...        Lane County
#
#         state  number classification
# 0  Washington    60.0        Class B
# 1    New York    70.0        Class B
# 2    Arkansas    76.0        Class B
# 3  Washington    77.0        Class B
# 4      Oregon    80.0        Class B

# %%
# double-check to make sure most necessary columns do not hold null values
# null values may be filled in merges
bf_reports_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# number            4747
# classification    4747
# dtype: int64

# %% [markdown]
# ### Compare counts of all three DFs

# %%
# Compare counts of all three df
bf_loc_transformed.count()
# Out:
# number            3994
# classification    3994
# latitude          3994
# longitude         3994
# Date_loc          3994
# Title             3994
# dtype: int64

# %%
# Compare counts of all three df
bf_geo_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# latitude          3797
# longitude         3797
# date              3797
# number            4747
# classification    4747
# geohash           3797
# dtype: int64

# %%
bf_reports_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# number            4747
# classification    4747
# dtype: int64

# %% [markdown]
# ## Merging of three dataframes

# %%
# Merge bf_geo_transformed and bf_reports_transformed DataFrames
bf_merge = pd.merge(bf_geo_transformed, bf_reports_transformed, on='number', how='outer', suffixes=("_geocoded", "_reports"))
bf_merge.head()
# Out:
#                                    observed_geocoded    county_geocoded  \
# 0  These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1  My wife and I were off the trail to take some ...  Washington County
# 2  I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3  We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4  My veterinarian sister, former girlfriend, and...        Lane County
#
#   state_geocoded  latitude  longitude        date  number  \
# 0     Washington  48.64056 -121.80530  1994-05-13    60.0
# 1       New York       NaN        NaN         NaN    70.0
# 2       Arkansas  36.37139  -92.25139  2001-08-11    76.0
# 3     Washington  46.98333 -121.09220  1983-09-01    77.0
# 4         Oregon  43.69005 -122.37550  1983-08-12    80.0
#
#   classification_geocoded     geohash  \
# 0                 Class B  c29ksq8pfc
# 1                 Class B         NaN
# 2                 Class B  9yqquv0wdy
# 3                 Class B  c23gk3p3ep
# 4                 Class B  9rbbx38bup
#
#                                     observed_reports     county_reports  \
# 0  These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1  My wife and I were off the trail to take some ...  Washington County
# 2  I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3  We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4  My veterinarian sister, former girlfriend, and...        Lane County
#
#   state_reports classification_reports
# 0    Washington                Class B
# 1      New York                Class B
# 2      Arkansas                Class B
# 3    Washington                Class B
# 4        Oregon                Class B

# %%
# Final merge with bf_loc_transformed into DataFrame and drop na
final_bf_merge = pd.merge(bf_merge, bf_loc_transformed, on='number', how='outer', suffixes=("_reports", "_location"))

final_bf_merge
# Out:
#                                       observed_geocoded    county_geocoded  \
# 0     These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1     My wife and I were off the trail to take some ...  Washington County
# 2     I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3     We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4     My veterinarian sister, former girlfriend, and...        Lane County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports        date   number  \
# 0        Washington          48.64056         -121.80530  1994-05-13     60.0
# 1          New York               NaN                NaN         NaN     70.0
# 2          Arkansas          36.37139          -92.25139  2001-08-11     76.0
# 3        Washington          46.98333         -121.09220  1983-09-01     77.0
# 4            Oregon          43.69005         -122.37550  1983-08-12     80.0
# ...             ...               ...                ...         ...      ...
# 4929            NaN               NaN                NaN         NaN  51949.0
# 4930            NaN               NaN                NaN         NaN  55604.0
# 4931            NaN               NaN                NaN         NaN  58445.0
# 4932            NaN               NaN                NaN         NaN  59610.0
# 4933            NaN               NaN                NaN         NaN  59728.0
#
#      classification_geocoded     geohash  \
# 0                    Class B  c29ksq8pfc
# 1                    Class B         NaN
# 2                    Class B  9yqquv0wdy
# 3                    Class B  c23gk3p3ep
# 4                    Class B  9rbbx38bup
# ...                      ...         ...
# 4929                     NaN         NaN
# 4930                     NaN         NaN
# 4931                     NaN         NaN
# 4932                     NaN         NaN
# 4933                     NaN         NaN
#
#                                        observed_reports     county_reports  \
# 0     These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1     My wife and I were off the trail to take some ...  Washington County
# 2     I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3     We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4     My veterinarian sister, former girlfriend, and...        Lane County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 0       Washington                Class B        Class B           48.64056
# 1         New York                Class B            NaN                NaN
# 2         Arkansas                Class B        Class B           36.37139
# 3       Washington                Class B        Class B           46.98333
# 4           Oregon                Class B        Class B           43.69005
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 0             -121.80530  1994-05-13
# 1                    NaN         NaN
# 2              -92.25139  2001-08-11
# 3             -121.09220  1983-09-01
# 4             -122.37550  1983-08-12
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 0             Missing Cattle and large footprints found
# 1                                                   NaN
# 2      Three fisherman hear thrashing about and loud...
# 3      Couple hear vocalizations while camping at Mi...
# 4      Late Arriving Campers Hear Running, Stomping,...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [4934 rows x 18 columns]

# %% [markdown]
# #### Dropping Duplicate/Incomplete Columns

# %% [markdown]
# ##### By comparing observed_geocoded and observed_reports, we see that the only values that do not match are NaN or 'None'.
# Because of this, we will drop the observed_reports.

# %%
# check to see if values from separate datasets match
# checking observation
final_bf_merge[final_bf_merge['observed_geocoded']!=final_bf_merge['observed_reports']]
# Out:
#      observed_geocoded   county_geocoded state_geocoded  latitude_reports  \
# 266                NaN  El Dorado County     California          38.93333
# 592                NaN     Morrow County           Ohio          40.38609
# 708                NaN   Le Flore County       Oklahoma          34.84167
# 924                NaN    Midland County       Michigan          43.79834
# 982                NaN     Monroe County      Tennessee          35.25970
# ...                ...               ...            ...               ...
# 4929               NaN               NaN            NaN               NaN
# 4930               NaN               NaN            NaN               NaN
# 4931               NaN               NaN            NaN               NaN
# 4932               NaN               NaN            NaN               NaN
# 4933               NaN               NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 266          -119.98330  1996-04-10    919.0                 Class A
# 592           -82.69884  1977-06-01   1625.0                 Class A
# 708           -94.63111  2001-03-20   1966.0                 Class B
# 924           -84.21140  1972-11-15   2830.0                 Class A
# 982           -84.28315  2000-08-03   3008.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  51949.0                     NaN
# 4930                NaN         NaN  55604.0                     NaN
# 4931                NaN         NaN  58445.0                     NaN
# 4932                NaN         NaN  59610.0                     NaN
# 4933                NaN         NaN  59728.0                     NaN
#
#          geohash observed_reports    county_reports state_reports  \
# 266   9qftmxwg46              NaN  El Dorado County    California
# 592   dpjjy0hd12              NaN     Morrow County          Ohio
# 708   9yhwnwexrq              NaN   Le Flore County      Oklahoma
# 924   dpu15tppu4              NaN    Midland County      Michigan
# 982   dnk0d4ffsk              NaN     Monroe County     Tennessee
# ...          ...              ...               ...           ...
# 4929         NaN              NaN               NaN           NaN
# 4930         NaN              NaN               NaN           NaN
# 4931         NaN              NaN               NaN           NaN
# 4932         NaN              NaN               NaN           NaN
# 4933         NaN              NaN               NaN           NaN
#
#      classification_reports classification  latitude_location  \
# 266                 Class A        Class A           38.93333
# 592                 Class A        Class A           40.38609
# 708                 Class B        Class B           34.84167
# 924                 Class A        Class A           43.79834
# 982                 Class A        Class A           35.25970
# ...                     ...            ...                ...
# 4929                    NaN        Class B           44.90046
# 4930                    NaN        Class B           52.78074
# 4931                    NaN        Class B           42.36689
# 4932                    NaN        Class B           50.81168
# 4933                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 266           -119.98330  1996-04-10
# 592            -82.69884  1977-06-01
# 708            -94.63111  2001-03-20
# 924            -84.21140  1972-11-15
# 982            -84.28315  2000-08-03
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 266    Car passenger has nighttime sighting near Lak...
# 592    Children have daytime close encounter near Sp...
# 708                     May/June 83/84 Oklahoma Leflore
# 924             BF shakes bush and screams at 2 hunters
# 982    Gold dredgers have afternoon encounter in Che...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [223 rows x 18 columns]

# %% [markdown]
# ##### Counties match except for NaN - will drop county_reports

# %%
# checking counties
final_bf_merge[final_bf_merge['county_geocoded']!=final_bf_merge['county_reports']]
# Out:
#      observed_geocoded county_geocoded state_geocoded  latitude_reports  \
# 4747               NaN             NaN            NaN               NaN
# 4748               NaN             NaN            NaN               NaN
# 4749               NaN             NaN            NaN               NaN
# 4750               NaN             NaN            NaN               NaN
# 4751               NaN             NaN            NaN               NaN
# ...                ...             ...            ...               ...
# 4929               NaN             NaN            NaN               NaN
# 4930               NaN             NaN            NaN               NaN
# 4931               NaN             NaN            NaN               NaN
# 4932               NaN             NaN            NaN               NaN
# 4933               NaN             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded geohash  \
# 4747                NaN  NaN    211.0                     NaN     NaN
# 4748                NaN  NaN    444.0                     NaN     NaN
# 4749                NaN  NaN    483.0                     NaN     NaN
# 4750                NaN  NaN    857.0                     NaN     NaN
# 4751                NaN  NaN   1528.0                     NaN     NaN
# ...                 ...  ...      ...                     ...     ...
# 4929                NaN  NaN  51949.0                     NaN     NaN
# 4930                NaN  NaN  55604.0                     NaN     NaN
# 4931                NaN  NaN  58445.0                     NaN     NaN
# 4932                NaN  NaN  59610.0                     NaN     NaN
# 4933                NaN  NaN  59728.0                     NaN     NaN
#
#      observed_reports county_reports state_reports classification_reports  \
# 4747              NaN            NaN           NaN                    NaN
# 4748              NaN            NaN           NaN                    NaN
# 4749              NaN            NaN           NaN                    NaN
# 4750              NaN            NaN           NaN                    NaN
# 4751              NaN            NaN           NaN                    NaN
# ...               ...            ...           ...                    ...
# 4929              NaN            NaN           NaN                    NaN
# 4930              NaN            NaN           NaN                    NaN
# 4931              NaN            NaN           NaN                    NaN
# 4932              NaN            NaN           NaN                    NaN
# 4933              NaN            NaN           NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc  \
# 4747        Class A           50.40230          -114.44190  1995-11-18
# 4748        Class C           33.49960           -84.54220  1986-04-15
# 4749        Class C           33.94175           -86.17965  1996-04-15
# 4750        Class B           49.70889          -125.25810  1968-09-24
# 4751        Class B           50.06295          -100.81880  2000-10-15
# ...             ...                ...                 ...         ...
# 4929        Class B           44.90046           -63.84574  2015-10-11
# 4930        Class B           52.78074          -116.36510  2016-09-06
# 4931        Class B           42.36689           -73.18228  2017-10-30
# 4932        Class B           50.81168          -114.78290  2018-06-12
# 4933        Class B           52.83539          -118.15610  2018-07-15
#
#                                                   Title
# 4747   Daylight sighting by a hunter east of Alberta...
# 4748   Family sightings over 100 years in Fayette an...
# 4749    Multiple witnesses describe multiple encounters
# 4750     Possible sighting around 2:00AM near Courtenay
# 4751   Possible sasquatch seen by farmer near Hwy 21...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [187 rows x 18 columns]

# %% [markdown]
# ##### States match except for NaN- will drop state_reports

# %%
# checking states
final_bf_merge[final_bf_merge['state_geocoded']!=final_bf_merge['state_reports']]
# Out:
#      observed_geocoded county_geocoded state_geocoded  latitude_reports  \
# 4747               NaN             NaN            NaN               NaN
# 4748               NaN             NaN            NaN               NaN
# 4749               NaN             NaN            NaN               NaN
# 4750               NaN             NaN            NaN               NaN
# 4751               NaN             NaN            NaN               NaN
# ...                ...             ...            ...               ...
# 4929               NaN             NaN            NaN               NaN
# 4930               NaN             NaN            NaN               NaN
# 4931               NaN             NaN            NaN               NaN
# 4932               NaN             NaN            NaN               NaN
# 4933               NaN             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded geohash  \
# 4747                NaN  NaN    211.0                     NaN     NaN
# 4748                NaN  NaN    444.0                     NaN     NaN
# 4749                NaN  NaN    483.0                     NaN     NaN
# 4750                NaN  NaN    857.0                     NaN     NaN
# 4751                NaN  NaN   1528.0                     NaN     NaN
# ...                 ...  ...      ...                     ...     ...
# 4929                NaN  NaN  51949.0                     NaN     NaN
# 4930                NaN  NaN  55604.0                     NaN     NaN
# 4931                NaN  NaN  58445.0                     NaN     NaN
# 4932                NaN  NaN  59610.0                     NaN     NaN
# 4933                NaN  NaN  59728.0                     NaN     NaN
#
#      observed_reports county_reports state_reports classification_reports  \
# 4747              NaN            NaN           NaN                    NaN
# 4748              NaN            NaN           NaN                    NaN
# 4749              NaN            NaN           NaN                    NaN
# 4750              NaN            NaN           NaN                    NaN
# 4751              NaN            NaN           NaN                    NaN
# ...               ...            ...           ...                    ...
# 4929              NaN            NaN           NaN                    NaN
# 4930              NaN            NaN           NaN                    NaN
# 4931              NaN            NaN           NaN                    NaN
# 4932              NaN            NaN           NaN                    NaN
# 4933              NaN            NaN           NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc  \
# 4747        Class A           50.40230          -114.44190  1995-11-18
# 4748        Class C           33.49960           -84.54220  1986-04-15
# 4749        Class C           33.94175           -86.17965  1996-04-15
# 4750        Class B           49.70889          -125.25810  1968-09-24
# 4751        Class B           50.06295          -100.81880  2000-10-15
# ...             ...                ...                 ...         ...
# 4929        Class B           44.90046           -63.84574  2015-10-11
# 4930        Class B           52.78074          -116.36510  2016-09-06
# 4931        Class B           42.36689           -73.18228  2017-10-30
# 4932        Class B           50.81168          -114.78290  2018-06-12
# 4933        Class B           52.83539          -118.15610  2018-07-15
#
#                                                   Title
# 4747   Daylight sighting by a hunter east of Alberta...
# 4748   Family sightings over 100 years in Fayette an...
# 4749    Multiple witnesses describe multiple encounters
# 4750     Possible sighting around 2:00AM near Courtenay
# 4751   Possible sasquatch seen by farmer near Hwy 21...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [187 rows x 18 columns]

# %% [markdown]
# ##### Latitude matches, but latitude_location is more complete - will drop latitude_reports

# %%
# checking latitude
final_bf_merge[final_bf_merge['latitude_reports']!=final_bf_merge['latitude_location']]
# Out:
#                                       observed_geocoded    county_geocoded  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 2     I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports        date   number  \
# 1          New York               NaN                NaN         NaN     70.0
# 2          Arkansas          36.37139          -92.25139  2001-08-11     76.0
# 5         Tennessee               NaN                NaN         NaN     81.0
# 12     Pennsylvania               NaN                NaN         NaN    105.0
# 19         New York               NaN                NaN         NaN    145.0
# ...             ...               ...                ...         ...      ...
# 4929            NaN               NaN                NaN         NaN  51949.0
# 4930            NaN               NaN                NaN         NaN  55604.0
# 4931            NaN               NaN                NaN         NaN  58445.0
# 4932            NaN               NaN                NaN         NaN  59610.0
# 4933            NaN               NaN                NaN         NaN  59728.0
#
#      classification_geocoded     geohash  \
# 1                    Class B         NaN
# 2                    Class B  9yqquv0wdy
# 5                    Class A         NaN
# 12                   Class A         NaN
# 19                   Class B         NaN
# ...                      ...         ...
# 4929                     NaN         NaN
# 4930                     NaN         NaN
# 4931                     NaN         NaN
# 4932                     NaN         NaN
# 4933                     NaN         NaN
#
#                                        observed_reports     county_reports  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 2     I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 1         New York                Class B            NaN                NaN
# 2         Arkansas                Class B        Class B           36.37139
# 5        Tennessee                Class A            NaN                NaN
# 12    Pennsylvania                Class A            NaN                NaN
# 19        New York                Class B            NaN                NaN
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 1                    NaN         NaN
# 2              -92.25139  2001-08-11
# 5                    NaN         NaN
# 12                   NaN         NaN
# 19                   NaN         NaN
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 1                                                   NaN
# 2      Three fisherman hear thrashing about and loud...
# 5                                                   NaN
# 12                                                  NaN
# 19                                                  NaN
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [1598 rows x 18 columns]

# %% [markdown]
# ##### Longitude matches, but longitude_location is more complete - will drop longitude_reports

# %%
# checking longitude
final_bf_merge[final_bf_merge['longitude_reports']!=final_bf_merge['longitude_location']]
# Out:
#                                       observed_geocoded    county_geocoded  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 11    This weekend 8/19/00 while hunting off of Salm...   Tillamook County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 14    Although I, nor my boys have actually seen a b...      Neosho County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports        date   number  \
# 1          New York               NaN                NaN         NaN     70.0
# 5         Tennessee               NaN                NaN         NaN     81.0
# 11           Oregon          45.73510         -123.46600  2000-08-19    102.0
# 12     Pennsylvania               NaN                NaN         NaN    105.0
# 14           Kansas          37.44208          -95.35479  1975-10-01    113.0
# ...             ...               ...                ...         ...      ...
# 4929            NaN               NaN                NaN         NaN  51949.0
# 4930            NaN               NaN                NaN         NaN  55604.0
# 4931            NaN               NaN                NaN         NaN  58445.0
# 4932            NaN               NaN                NaN         NaN  59610.0
# 4933            NaN               NaN                NaN         NaN  59728.0
#
#      classification_geocoded     geohash  \
# 1                    Class B         NaN
# 5                    Class A         NaN
# 11                   Class B  c20hnmyf38
# 12                   Class A         NaN
# 14                   Class B  9ysjn0hgbm
# ...                      ...         ...
# 4929                     NaN         NaN
# 4930                     NaN         NaN
# 4931                     NaN         NaN
# 4932                     NaN         NaN
# 4933                     NaN         NaN
#
#                                        observed_reports     county_reports  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 11    This weekend 8/19/00 while hunting off of Salm...   Tillamook County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 14    Although I, nor my boys have actually seen a b...      Neosho County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 1         New York                Class B            NaN                NaN
# 5        Tennessee                Class A            NaN                NaN
# 11          Oregon                Class B        Class B           45.73510
# 12    Pennsylvania                Class A            NaN                NaN
# 14          Kansas                Class B        Class B           37.44208
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 1                    NaN         NaN
# 5                    NaN         NaN
# 11            -123.46600  2000-08-19
# 12                   NaN         NaN
# 14             -95.35479  1975-10-01
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 1                                                   NaN
# 5                                                   NaN
# 11     Couple hears unknown howl, later finds possib...
# 12                                                  NaN
# 14     Son and friend find footprints. Later somethi...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [1519 rows x 18 columns]

# %% [markdown]
# ##### Dates match, but date_loc is more complete - will drop date

# %%
# checking longitude
final_bf_merge[final_bf_merge['date']!=final_bf_merge['Date_loc']]
# Out:
#                                       observed_geocoded    county_geocoded  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports date   number  \
# 1          New York               NaN                NaN  NaN     70.0
# 5         Tennessee               NaN                NaN  NaN     81.0
# 12     Pennsylvania               NaN                NaN  NaN    105.0
# 19         New York               NaN                NaN  NaN    145.0
# 21       California               NaN                NaN  NaN    160.0
# ...             ...               ...                ...  ...      ...
# 4929            NaN               NaN                NaN  NaN  51949.0
# 4930            NaN               NaN                NaN  NaN  55604.0
# 4931            NaN               NaN                NaN  NaN  58445.0
# 4932            NaN               NaN                NaN  NaN  59610.0
# 4933            NaN               NaN                NaN  NaN  59728.0
#
#      classification_geocoded geohash  \
# 1                    Class B     NaN
# 5                    Class A     NaN
# 12                   Class A     NaN
# 19                   Class B     NaN
# 21                   Class B     NaN
# ...                      ...     ...
# 4929                     NaN     NaN
# 4930                     NaN     NaN
# 4931                     NaN     NaN
# 4932                     NaN     NaN
# 4933                     NaN     NaN
#
#                                        observed_reports     county_reports  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 1         New York                Class B            NaN                NaN
# 5        Tennessee                Class A            NaN                NaN
# 12    Pennsylvania                Class A            NaN                NaN
# 19        New York                Class B            NaN                NaN
# 21      California                Class B            NaN                NaN
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 1                    NaN         NaN
# 5                    NaN         NaN
# 12                   NaN         NaN
# 19                   NaN         NaN
# 21                   NaN         NaN
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 1                                                   NaN
# 5                                                   NaN
# 12                                                  NaN
# 19                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [1137 rows x 18 columns]

# %% [markdown]
# ##### Checking classifications - many holes in each.
# Will remove to own dataframe.

# %%
# checking classification
final_bf_merge[final_bf_merge['classification']!=final_bf_merge['classification_geocoded']]
# Out:
#                                       observed_geocoded    county_geocoded  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports date   number  \
# 1          New York               NaN                NaN  NaN     70.0
# 5         Tennessee               NaN                NaN  NaN     81.0
# 12     Pennsylvania               NaN                NaN  NaN    105.0
# 19         New York               NaN                NaN  NaN    145.0
# 21       California               NaN                NaN  NaN    160.0
# ...             ...               ...                ...  ...      ...
# 4929            NaN               NaN                NaN  NaN  51949.0
# 4930            NaN               NaN                NaN  NaN  55604.0
# 4931            NaN               NaN                NaN  NaN  58445.0
# 4932            NaN               NaN                NaN  NaN  59610.0
# 4933            NaN               NaN                NaN  NaN  59728.0
#
#      classification_geocoded geohash  \
# 1                    Class B     NaN
# 5                    Class A     NaN
# 12                   Class A     NaN
# 19                   Class B     NaN
# 21                   Class B     NaN
# ...                      ...     ...
# 4929                     NaN     NaN
# 4930                     NaN     NaN
# 4931                     NaN     NaN
# 4932                     NaN     NaN
# 4933                     NaN     NaN
#
#                                        observed_reports     county_reports  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 1         New York                Class B            NaN                NaN
# 5        Tennessee                Class A            NaN                NaN
# 12    Pennsylvania                Class A            NaN                NaN
# 19        New York                Class B            NaN                NaN
# 21      California                Class B            NaN                NaN
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 1                    NaN         NaN
# 5                    NaN         NaN
# 12                   NaN         NaN
# 19                   NaN         NaN
# 21                   NaN         NaN
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 1                                                   NaN
# 5                                                   NaN
# 12                                                  NaN
# 19                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [1127 rows x 18 columns]

# %%
# checking classification
final_bf_merge[final_bf_merge['classification']!=final_bf_merge['classification_reports']]
# Out:
#                                       observed_geocoded    county_geocoded  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_geocoded  latitude_reports  longitude_reports date   number  \
# 1          New York               NaN                NaN  NaN     70.0
# 5         Tennessee               NaN                NaN  NaN     81.0
# 12     Pennsylvania               NaN                NaN  NaN    105.0
# 19         New York               NaN                NaN  NaN    145.0
# 21       California               NaN                NaN  NaN    160.0
# ...             ...               ...                ...  ...      ...
# 4929            NaN               NaN                NaN  NaN  51949.0
# 4930            NaN               NaN                NaN  NaN  55604.0
# 4931            NaN               NaN                NaN  NaN  58445.0
# 4932            NaN               NaN                NaN  NaN  59610.0
# 4933            NaN               NaN                NaN  NaN  59728.0
#
#      classification_geocoded geohash  \
# 1                    Class B     NaN
# 5                    Class A     NaN
# 12                   Class A     NaN
# 19                   Class B     NaN
# 21                   Class B     NaN
# ...                      ...     ...
# 4929                     NaN     NaN
# 4930                     NaN     NaN
# 4931                     NaN     NaN
# 4932                     NaN     NaN
# 4933                     NaN     NaN
#
#                                        observed_reports     county_reports  \
# 1     My wife and I were off the trail to take some ...  Washington County
# 5     when we toped a small hill and started down th...       Lewis County
# 12    It was September of 1997 and I was outside on ...   Allegheny County
# 19    This incident occurred in late February of 198...     Chemung County
# 21    A tremendous storm came in off the Pacific.  M...     Trinity County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 1         New York                Class B            NaN                NaN
# 5        Tennessee                Class A            NaN                NaN
# 12    Pennsylvania                Class A            NaN                NaN
# 19        New York                Class B            NaN                NaN
# 21      California                Class B            NaN                NaN
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           44.90046
# 4930           NaN                    NaN        Class B           52.78074
# 4931           NaN                    NaN        Class B           42.36689
# 4932           NaN                    NaN        Class B           50.81168
# 4933           NaN                    NaN        Class B           52.83539
#
#       longitude_location    Date_loc  \
# 1                    NaN         NaN
# 5                    NaN         NaN
# 12                   NaN         NaN
# 19                   NaN         NaN
# 21                   NaN         NaN
# ...                  ...         ...
# 4929           -63.84574  2015-10-11
# 4930          -116.36510  2016-09-06
# 4931           -73.18228  2017-10-30
# 4932          -114.78290  2018-06-12
# 4933          -118.15610  2018-07-15
#
#                                                   Title
# 1                                                   NaN
# 5                                                   NaN
# 12                                                  NaN
# 19                                                  NaN
# 21                                                  NaN
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [1127 rows x 18 columns]

# %% [markdown]
# ##### Remove classifications to their own dataframe, since they do not match.

# %%
# select number and classifications to add to separate classification dataframe
classification_cols = ['number', 'classification', 'classification_geocoded', 'classification_reports']
classification = final_bf_merge[classification_cols].copy()
classification
# Out:
#        number classification classification_geocoded classification_reports
# 0        60.0        Class B                 Class B                Class B
# 1        70.0            NaN                 Class B                Class B
# 2        76.0        Class B                 Class B                Class B
# 3        77.0        Class B                 Class B                Class B
# 4        80.0        Class B                 Class B                Class B
# ...       ...            ...                     ...                    ...
# 4929  51949.0        Class B                     NaN                    NaN
# 4930  55604.0        Class B                     NaN                    NaN
# 4931  58445.0        Class B                     NaN                    NaN
# 4932  59610.0        Class B                     NaN                    NaN
# 4933  59728.0        Class B                     NaN                    NaN
#
# [4934 rows x 4 columns]

# %% [markdown]
# ##### Drop unnecessary columns
# * observed_reports
# * county_reports
# * state_reports
# * latitude_reports
# * longitude_reports
# * date
# * classification
# * classification_geocoded
# * classification_reports

# %%
# drop columns
bigfoot_data = final_bf_merge.drop(['observed_reports',
                                    'county_reports',
                                    'state_reports',
                                    'latitude_reports',
                                    'longitude_reports',
                                    'date',
                                    'classification',
                                    'classification_geocoded',
                                    'classification_reports'
                                       ], axis=1)

# Rename column headers
bigfoot_data = bigfoot_data.rename(columns={'observed_geocoded':'observation',
                                            'county_geocoded':'county',
                                            'state_geocoded':'state',
                                            'latitude_location':'latitude',
                                            'longitude_location':'longitude',
                                            'Date_loc':'date',
                                            'Title':'moreInfo'})

bigfoot_data
# Out:
#                                             observation             county  \
# 0     These two gentlmen, brothers, recluses age 50'...      Skagit County
# 1     My wife and I were off the trail to take some ...  Washington County
# 2     I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...      Baxter County
# 3     We had driven into Milk pond, up Chinook pass,...    Kittitas County
# 4     My veterinarian sister, former girlfriend, and...        Lane County
# ...                                                 ...                ...
# 4929                                                NaN                NaN
# 4930                                                NaN                NaN
# 4931                                                NaN                NaN
# 4932                                                NaN                NaN
# 4933                                                NaN                NaN
#
#            state   number     geohash  latitude  longitude        date  \
# 0     Washington     60.0  c29ksq8pfc  48.64056 -121.80530  1994-05-13
# 1       New York     70.0         NaN       NaN        NaN         NaN
# 2       Arkansas     76.0  9yqquv0wdy  36.37139  -92.25139  2001-08-11
# 3     Washington     77.0  c23gk3p3ep  46.98333 -121.09220  1983-09-01
# 4         Oregon     80.0  9rbbx38bup  43.69005 -122.37550  1983-08-12
# ...          ...      ...         ...       ...        ...         ...
# 4929         NaN  51949.0         NaN  44.90046  -63.84574  2015-10-11
# 4930         NaN  55604.0         NaN  52.78074 -116.36510  2016-09-06
# 4931         NaN  58445.0         NaN  42.36689  -73.18228  2017-10-30
# 4932         NaN  59610.0         NaN  50.81168 -114.78290  2018-06-12
# 4933         NaN  59728.0         NaN  52.83539 -118.15610  2018-07-15
#
#                                                moreInfo
# 0             Missing Cattle and large footprints found
# 1                                                   NaN
# 2      Three fisherman hear thrashing about and loud...
# 3      Couple hear vocalizations while camping at Mi...
# 4      Late Arriving Campers Hear Running, Stomping,...
# ...                                                 ...
# 4929   Large rock flung at two hikers visiting Mount...
# 4930   Two hunters experience prolonged tree shaking...
# 4931   Camper has an unnerving night on October Moun...
# 4932   Retired mail carrier reports sundown knocks a...
# 4933   Hiker finds possible tracks in Indian Ridge a...
#
# [4934 rows x 9 columns]

# %% [markdown]
# ##### Separate file into location data and observation data

# %%
sighting_location = bigfoot_data[['number','county','state','latitude','longitude','geohash', 'date']]
sighting_location.head()
# Out:
#    number             county       state  latitude  longitude     geohash  \
# 0    60.0      Skagit County  Washington  48.64056 -121.80530  c29ksq8pfc
# 1    70.0  Washington County    New York       NaN        NaN         NaN
# 2    76.0      Baxter County    Arkansas  36.37139  -92.25139  9yqquv0wdy
# 3    77.0    Kittitas County  Washington  46.98333 -121.09220  c23gk3p3ep
# 4    80.0        Lane County      Oregon  43.69005 -122.37550  9rbbx38bup
#
#          date
# 0  1994-05-13
# 1         NaN
# 2  2001-08-11
# 3  1983-09-01
# 4  1983-08-12

# %%
observations = bigfoot_data[['number','date','observation','moreInfo']]
observations.head()
# Out:
#    number        date                                        observation  \
# 0    60.0  1994-05-13  These two gentlmen, brothers, recluses age 50'...
# 1    70.0         NaN  My wife and I were off the trail to take some ...
# 2    76.0  2001-08-11  I DID NOT SEE ANYTHING.  I DID HEAR A LOT.  WH...
# 3    77.0  1983-09-01  We had driven into Milk pond, up Chinook pass,...
# 4    80.0  1983-08-12  My veterinarian sister, former girlfriend, and...
#
#                                             moreInfo
# 0          Missing Cattle and large footprints found
# 1                                                NaN
# 2   Three fisherman hear thrashing about and loud...
# 3   Couple hear vocalizations while camping at Mi...
# 4   Late Arriving Campers Hear Running, Stomping,...

# %%
# create output files
output_file = 'templates/bigfootData.json'
sighting_output = 'templates/sightingsLocation.json'
observation_output = 'templates/observationReports.json'

# %%
# write all data to json
bigfootData = bigfoot_data.to_json(output_file, orient='index')
bigfootData

# %%
# write sightings data to json
sightings = sighting_location.to_json(sighting_output, orient='index')
sightings

# %%
# write sightings data to json
observationReports = observations.to_json(observation_output, orient='index')
observationReports

# %% [markdown]
# Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/Bigfoot"
engine = create_engine(f'postgresql://{connection_string}')
