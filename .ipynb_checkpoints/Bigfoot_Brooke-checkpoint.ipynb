# %%
#Import libraries 

import pandas as pd
from sqlalchemy import create_engine
# import json

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %%
#Store Data in Dataframe

csv_loc = "Resources/bfro_report_locations.csv"
csv_geo = "Resources/bfro_reports_geocoded.csv"
json_file = "Resources/bfro_reports.json"

bigfoot_locations_df = pd.read_csv(csv_loc)
bigfoot_geo_df = pd.read_csv(csv_geo)
bfro_rep_df = pd.read_json(json_file, lines=True)

# %%
# Display location CSV DataFrame
bigfoot_locations_df.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
# Begin filtering data

bf_loc_cols = ["number", "classification", 'timestamp', 'latitude', 'longitude']
bf_loc_transformed = bigfoot_locations_df[bf_loc_cols].copy()

# Drop null values on 'number'
bf_loc_transformed = bf_loc_transformed[bf_loc_transformed['number'].notna()]

bf_loc_transformed.head()
# Out:
#    number classification             timestamp  latitude  longitude
# 0     637        Class A  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1    2917        Class A  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2    7963        Class A  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3    9317        Class A  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4   13038        Class A  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
bf_loc_transformed.count()
# Out:
# number            3994
# classification    3994
# timestamp         3994
# latitude          3994
# longitude         3994
# dtype: int64

# %%
bigfoot_geo_df.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# 4                     Ward County   North Dakota  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 55269: Dawn sighting at Stevens Brook o...  43.41549  -72.33093
# 3  Report 59757: Possible daylight sighting of a ...  42.15685  -96.34203
# 4  Report 751: Hunter describes described being s...  48.25422 -101.31660
#
#          date   number     ...     moon_phase precip_intensity  \
# 0         NaN   1261.0     ...            NaN              NaN
# 1         NaN    438.0     ...            NaN              NaN
# 2  2016-06-07  55269.0     ...           0.10            0.001
# 3  2018-05-25  59757.0     ...           0.38            0.000
# 4  2000-04-21    751.0     ...           0.60              NaN
#
#    precip_probability  precip_type  pressure  \
# 0                 NaN          NaN       NaN
# 1                 NaN          NaN       NaN
# 2                 0.7         rain    998.87
# 3                 0.0          NaN   1008.07
# 4                 NaN         rain   1011.47
#
#                              summary  uv_index  visibility  wind_bearing  \
# 0                                NaN       NaN         NaN           NaN
# 1                                NaN       NaN         NaN           NaN
# 2  Mostly cloudy throughout the day.       6.0        9.70         262.0
# 3      Partly cloudy in the morning.      10.0        8.25         193.0
# 4       Partly cloudy until evening.       6.0       10.00         237.0
#
#    wind_speed
# 0         NaN
# 1         NaN
# 2        0.49
# 3        3.33
# 4       11.14
#
# [5 rows x 28 columns]

# %%
bigfoot_geo_df.count()
# Out:
# observed              4711
# location_details      4009
# county                4747
# state                 4747
# season                4747
# title                 3797
# latitude              3797
# longitude             3797
# date                  3797
# number                4747
# classification        4747
# geohash               3797
# temperature_high      3098
# temperature_mid       2950
# temperature_low       2953
# dew_point             3133
# humidity              3133
# cloud_cover           2853
# moon_phase            3156
# precip_intensity      2493
# precip_probability    2493
# precip_type           1560
# pressure              2411
# summary               3156
# uv_index              3156
# visibility            2817
# wind_bearing          3147
# wind_speed            3149
# dtype: int64

# %%
# Begin filtering data
bf_geo_cols = ['observed', 'county', 'state', 'latitude', 'longitude', 'date','number', 'classification']
bf_geo_transformed = bigfoot_geo_df[bf_geo_cols].copy()

# Drop null values on 'number'
bf_geo_transformed = bf_geo_transformed[bf_geo_transformed['number'].notna()]

bf_geo_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                            county          state  latitude  longitude  \
# 0  Valdez-Chitina-Whittier County         Alaska       NaN        NaN
# 1                   Warren County     New Jersey       NaN        NaN
# 2                 Sullivan County  New Hampshire  43.41549  -72.33093
# 3                 Thurston County       Nebraska  42.15685  -96.34203
# 4                     Ward County   North Dakota  48.25422 -101.31660
#
#          date   number classification
# 0         NaN   1261.0        Class A
# 1         NaN    438.0        Class B
# 2  2016-06-07  55269.0        Class A
# 3  2018-05-25  59757.0        Class B
# 4  2000-04-21    751.0        Class A

# %%
bfro_rep_df.head()
# Out:
#                                         ALSO_NOTICED A_&_G_References  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                            nothing              NaN
# 3                                                NaN              NaN
# 4  I had audio recorders set up in the area and r...              NaN
#
#                            COUNTY        DATE  \
# 0  Valdez-Chitina-Whittier County         NaN
# 1                             NaN         NaN
# 2                   Warren County  2nd or 3rd
# 3                 Sullivan County           7
# 4                 Thurston County          25
#
#                                          ENVIRONMENT  \
# 0                                                NaN
# 1                                                NaN
# 2  good size river, steep hills, very rugged area...
# 3  swamp with forest behind it. There was a large...
# 4  This is a heavily forested area bordering the ...
#
#                                     LOCATION_DETAILS      MONTH  \
# 0                  East side of Prince William Sound        NaN
# 1                                                NaN        NaN
# 2  the road is off us rt 80, i dont know the exit...  September
# 3  Close to Claremont down 120 not far from Kings...       June
# 4      Latitude & Longitude :  42.158230  -96.344197        May
#
#            NEAREST_ROAD NEAREST_TOWN  \
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2  not sure of the road    Allumuchy
# 3               Rte 120    Claremont
# 4           Highway 201         Macy
#
#                                             OBSERVED  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1                                                NaN
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
#
#                                        OTHER_STORIES  \
# 0                                                NaN
# 1                                                NaN
# 2  no but after the events stated i looked at you...
# 3                                                NaN
# 4  There are MANY encounters in this general area...
#
#                                      OTHER_WITNESSES REPORT_CLASS  \
# 0  On a commercial fishing boat at anchor at the ...      Class A
# 1                                                NaN         None
# 2  my friend was asleep, and i was lying next to ...      Class B
# 3                                        Just myself      Class A
# 4  2 witnesses saw the creature. 3 people were pr...      Class B
#
#    REPORT_NUMBER  SEASON          STATE  \
# 0         1261.0    Fall         Alaska
# 1            NaN     NaN            NaN
# 2          438.0    Fall     New Jersey
# 3        55269.0  Summer  New Hampshire
# 4        59757.0  Spring       Nebraska
#
#                                  TIME_AND_CONDITIONS          YEAR
# 0                   Early Fall, in the early 1990's.  Early 1990's
# 1                                                NaN           NaN
# 2  lighting was from a camp fire that was dieing ...          2000
# 3                           5am. Dawn. Clear weather          2016
# 4  1:35 pm on a clear and very hot sunny day. Tem...          2018

# %%
# Begin filtering json data
bf_reports_cols = ['OBSERVED', 'COUNTY', 'STATE', 'YEAR', 'MONTH', 'REPORT_NUMBER', 'REPORT_CLASS']
bf_reports_transformed = bfro_rep_df[bf_reports_cols].copy()

# Rename column headers
bf_reports_transformed = bf_reports_transformed.rename(columns={"OBSERVED": 'observed',
                                                               'COUNTY': 'county',
                                                               'STATE': 'state',
                                                                'YEAR': 'year',
                                                               'MONTH': 'month',
                                                               'REPORT_NUMBER': 'number',
                                                               'REPORT_CLASS': 'classification'})

# Drop null values on 'number'
bf_reports_transformed = bf_reports_transformed[bf_reports_transformed['number'].notna()]

bf_reports_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
# 5  While this incident occurred a long time ago, ...
#
#                            county          state          year      month  \
# 0  Valdez-Chitina-Whittier County         Alaska  Early 1990's        NaN
# 2                   Warren County     New Jersey          2000  September
# 3                 Sullivan County  New Hampshire          2016       June
# 4                 Thurston County       Nebraska          2018        May
# 5                     Ward County   North Dakota          1962      April
#
#     number classification
# 0   1261.0        Class A
# 2    438.0        Class B
# 3  55269.0        Class A
# 4  59757.0        Class B
# 5    751.0        Class A

# %%
bf_reports_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# year              4746
# month             4145
# number            4747
# classification    4747
# dtype: int64

# %%
# Merge bf_geo_transformed and bf_reports_transformed DataFrames
bf_merge = pd.merge(bf_geo_transformed, bf_reports_transformed, on='number', how='outer', suffixes=("_geocoded", "_reports"))
bf_merge.head()
# Out:
#                                    observed_geocoded  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                   county_geocoded state_geocoded  latitude  longitude  \
# 0  Valdez-Chitina-Whittier County         Alaska       NaN        NaN
# 1                   Warren County     New Jersey       NaN        NaN
# 2                 Sullivan County  New Hampshire  43.41549  -72.33093
# 3                 Thurston County       Nebraska  42.15685  -96.34203
# 4                     Ward County   North Dakota  48.25422 -101.31660
#
#          date   number classification_geocoded  \
# 0         NaN   1261.0                 Class A
# 1         NaN    438.0                 Class B
# 2  2016-06-07  55269.0                 Class A
# 3  2018-05-25  59757.0                 Class B
# 4  2000-04-21    751.0                 Class A
#
#                                     observed_reports  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                    county_reports  state_reports          year      month  \
# 0  Valdez-Chitina-Whittier County         Alaska  Early 1990's        NaN
# 1                   Warren County     New Jersey          2000  September
# 2                 Sullivan County  New Hampshire          2016       June
# 3                 Thurston County       Nebraska          2018        May
# 4                     Ward County   North Dakota          1962      April
#
#   classification_reports
# 0                Class A
# 1                Class B
# 2                Class A
# 3                Class B
# 4                Class A

# %%
# Final merge with bf_loc_transformed into DataFrame and drop na
final_bf_merge = pd.merge(bf_merge, bf_loc_transformed, on='number', how='outer')
final_bf_merge.dropna()
# Out:
#                                       observed_geocoded      county_geocoded  \
# 2     I was on my way to Claremont from Lebanon on R...      Sullivan County
# 3     I was northeast of Macy Nebraska along the Mis...      Thurston County
# 4     While this incident occurred a long time ago, ...          Ward County
# 5     In early spring 1988, some friends of mine and...        Yancey County
# 6     This happened summertime early 70's (I think 7...    Stillwater County
# 4731        Class B  2010-10-05T12:00:00Z    38.39027    -85.95914
# 4733        Class A  1973-09-08T12:00:00Z    40.18000    -86.15120
# 4734        Class B  2001-07-15T12:00:00Z    38.02847    -85.57882
# 4736        Class B  2002-07-01T12:00:00Z    40.74765    -85.57069
# 4738        Class A  2005-01-21T12:00:00Z    39.35790    -85.61000
# 4740        Class B  2004-06-12T12:00:00Z    38.41910    -86.23506
# 4744        Class B  2015-08-08T12:00:00Z    39.17909    -86.33560
#
# [3333 rows x 18 columns]

# %%
# Clean up final merge Dataframe to rename columns
final_bf_merge = final_bf_merge.rename(columns={"OBSERVED": 'observed',
                                                               'COUNTY': 'county',
                                                               'STATE': 'state',
                                                                'YEAR': 'year',
                                                               'MONTH': 'month',
                                                               'REPORT_NUMBER': 'number',
                                                               'REPORT_CLASS': 'classification'})

# %%
x_classifications['class'] = final_bf_merge['classification_x'] + final_bf_merge['classification_y']
x_classifications.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'classification_x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-bda7c540826b> in <module>
#       1
# ----> 2 x_classifications['class'] = final_bf_merge['classification_x'] + final_bf_merge['classification_y']
#       3 x_classifications.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'classification_x'

# %%
classification_table = x_classifications + final_bf_merge['classification']
cleaned_classifications = classification_table.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5f1ff41fc717> in <module>
# ----> 1 classification_table = x_classifications + final_bf_merge['classification']
#       2 cleaned_classifications = classification_table.dropna()
#
# NameError: name 'x_classifications' is not defined

# %%
x = cleaned_classifications.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0a5011c0bea2> in <module>
# ----> 1 x = cleaned_classifications.drop_duplicates()
#
# NameError: name 'cleaned_classifications' is not defined

# %%
clean_df = pd.DataFrame(x)
clean_df.columns = ['classificiation']
clean_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-80fd297887cb> in <module>
# ----> 1 clean_df = pd.DataFrame(x)
#       2 clean_df.columns = ['classificiation']
#       3 clean_df
#
# NameError: name 'x' is not defined

# %%
y_classifications = final_bf_merge['classification_y']
y_classifications
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'classification_y'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-9d4490137b74> in <module>
# ----> 1 y_classifications = final_bf_merge['classification_y']
#       2 y_classifications
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'classification_y'

# %%
classifications = final_bf_merge['classification']
classifications
# Out:
# 0           NaN
# 1           NaN
# 2       Class A
# 3       Class B
# 4       Class A
# 5       Class B
# 6       Class B
# 7       Class B
# 8       Class B
# 9           NaN
# 10      Class B
# 11          NaN
# 12          NaN
# 13      Class A
# 14      Class A
# 15      Class B
# 16      Class B
# 17      Class B
# 18      Class A
# 19      Class B
# 20          NaN
# 21      Class B
# 22          NaN
# 23      Class B
# 24      Class B
# 25      Class A
# 26      Class B
# 27          NaN
# 28      Class A
# 29      Class A
#          ...
# 4904    Class B
# 4905    Class B
# 4906    Class B
# 4907    Class B
# 4908    Class B
# 4909    Class B
# 4910    Class B
# 4911    Class B
# 4912    Class B
# 4913    Class B
# 4914    Class B
# 4915    Class B
# 4916    Class B
# 4917    Class B
# 4918    Class B
# 4919    Class B
# 4920    Class B
# 4921    Class B
# 4922    Class B
# 4923    Class B
# 4924    Class B
# 4925    Class B
# 4926    Class B
# 4927    Class B
# 4928    Class B
# 4929    Class B
# 4930    Class B
# 4931    Class C
# 4932    Class C
# 4933    Class C
# Name: classification, Length: 4934, dtype: object

# %%
#list of columns from dataframes

bigfoot_locations_df.head()
list_loc=[]
for col in bigfoot_locations_df.columns: 
    list_loc.append(col)

# %%
#bigfoot_geo_df.head()
list_geo=[]
for col in bigfoot_geo_df.columns: 
    list_geo.append(col)

# %%
inter=intersection(list_geo, list_loc)

# %%
bf_geo=bigfoot_geo_df[inter]
bf_geo=bf_geo[['number','title','classification','latitude','longitude']]

#final=pd.concat([ye,bigfoot_locations_df])

# %%
#bfro_rep_df.head()

geo_nums=bf_geo_transformed['number'].tolist()
loc_nums=bigfoot_locations_df['number'].tolist()
intr_nums=intersection(geo_nums,loc_nums)
print(len(geo_nums))
print(len(loc_nums))
print(len(intr_nums))
# Out:
# 4747
# 3994
# 3807

# %%
# sanity check
for loc in loc_nums:
    if loc not in geo_nums:
        print(loc)
# Out:
# 211
# 9876
# 10775
# 12001
# 12647
# 17290
# 27043
# 38116
# 43598
# 2113
# 3899
# 4900
# 5172
# 6831
# 10001
# 10633
# 10878
# 11915
# 12451
# 13232
# 13371
# 13464
# 13642
# 14328
# 14329
# 14511
# 15085
# 15274
# 17331
# 18534
# 20415
# 21563
# 23245
# 24564
# 24806
# 26050
# 26765
# 28740
# 34822
# 2404
# 8576
# 12335
# 12908
# 21795
# 35177
# 15343
# 17221
# 1615
# 5873
# 9516
# 10611
# 13267
# 13627
# 16807
# 16853
# 18077
# 20408
# 22821
# 23134
# 23171
# 24733
# 25857
# 31992
# 13061
# 16779
# 7436
# 24826
# 1776
# 2017
# 10974
# 6486
# 2069
# 6829
# 10127
# 10597
# 10883
# 15835
# 23259
# 25378
# 26517
# 26746
# 27154
# 27910
# 28583
# 34794
# 55604
# 59610
# 59728
# 857
# 2852
# 3945
# 5041
# 6579
# 7456
# 7911
# 9069
# 9438
# 9654
# 9778
# 10572
# 10864
# 11570
# 11595
# 12100
# 12855
# 13390
# 13427
# 13583
# 13800
# 13815
# 14020
# 14166
# 14344
# 15141
# 15389
# 15419
# 15541
# 15571
# 15888
# 15961
# 17142
# 17178
# 18115
# 18441
# 18913
# 20758
# 22123
# 24039
# 24377
# 24956
# 25140
# 25368
# 26821
# 27281
# 28285
# 35539
# 35773
# 40024
# 40345
# 43994
# 1528
# 9142
# 9495
# 23849
# 26331
# 31176
# 50446
# 51949
# 7943
# 10308
# 10734
# 11797
# 12958
# 13706
# 14341
# 14981
# 16719
# 16944
# 17443
# 17457
# 17501
# 18375
# 23490
# 24881
# 25229
# 25670
# 26285
# 26348
# 27180
# 27959
# 27961
# 30249
# 6833
# 11170
# 17214
# 23086
# 2815
# 12733
# 14405
# 17456
# 24643
# 12088
# 58445
# 10445
# 483
# 25381
# 444

# %%
# another sanity check
report_nums = bf_reports_transformed['number'].tolist()
inter_nums = intersection(report_nums,geo_nums) 
print(len(inter_nums))
# Out:
# 4747

# %% [markdown]
# Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/bigfoot_db"
engine = create_engine(f'postgresql://{connection_string}')
