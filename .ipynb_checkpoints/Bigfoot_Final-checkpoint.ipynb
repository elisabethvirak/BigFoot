# %%
#Import libraries 

import pandas as pd
from sqlalchemy import create_engine
# import json

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %%
#Store Data in Dataframe

csv_loc = "Resources/bfro_report_locations.csv"
csv_geo = "Resources/bfro_reports_geocoded.csv"
json_file = "Resources/bfro_reports.json"

bigfoot_locations_df = pd.read_csv(csv_loc)
bigfoot_geo_df = pd.read_csv(csv_geo)
bfro_rep_df = pd.read_json(json_file, lines=True)

# %%
# Display location CSV DataFrame
bigfoot_locations_df.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
# Begin filtering data

bf_loc_cols = ["number", "classification", 'timestamp', 'latitude', 'longitude']
bf_loc_transformed = bigfoot_locations_df[bf_loc_cols].copy()

# Drop null values on 'number'
bf_loc_transformed = bf_loc_transformed[bf_loc_transformed['number'].notna()]

bf_loc_transformed.head()
# Out:
#    number classification             timestamp  latitude  longitude
# 0     637        Class A  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1    2917        Class A  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2    7963        Class A  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3    9317        Class A  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4   13038        Class A  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
bf_loc_transformed.count()
# Out:
# number            3994
# classification    3994
# timestamp         3994
# latitude          3994
# longitude         3994
# dtype: int64

# %%
bigfoot_geo_df.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# 4                     Ward County   North Dakota  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 55269: Dawn sighting at Stevens Brook o...  43.41549  -72.33093
# 3  Report 59757: Possible daylight sighting of a ...  42.15685  -96.34203
# 4  Report 751: Hunter describes described being s...  48.25422 -101.31660
#
#          date   number  ... moon_phase precip_intensity  precip_probability  \
# 0         NaN   1261.0  ...        NaN              NaN                 NaN
# 1         NaN    438.0  ...        NaN              NaN                 NaN
# 2  2016-06-07  55269.0  ...       0.10            0.001                 0.7
# 3  2018-05-25  59757.0  ...       0.38            0.000                 0.0
# 4  2000-04-21    751.0  ...       0.60              NaN                 NaN
#
#    precip_type  pressure                            summary  uv_index  \
# 0          NaN       NaN                                NaN       NaN
# 1          NaN       NaN                                NaN       NaN
# 2         rain    998.87  Mostly cloudy throughout the day.       6.0
# 3          NaN   1008.07      Partly cloudy in the morning.      10.0
# 4         rain   1011.47       Partly cloudy until evening.       6.0
#
#    visibility  wind_bearing  wind_speed
# 0         NaN           NaN         NaN
# 1         NaN           NaN         NaN
# 2        9.70         262.0        0.49
# 3        8.25         193.0        3.33
# 4       10.00         237.0       11.14
#
# [5 rows x 28 columns]

# %%
bigfoot_geo_df.count()
# Out:
# observed              4711
# location_details      4009
# county                4747
# state                 4747
# season                4747
# title                 3797
# latitude              3797
# longitude             3797
# date                  3797
# number                4747
# classification        4747
# geohash               3797
# temperature_high      3098
# temperature_mid       2950
# temperature_low       2953
# dew_point             3133
# humidity              3133
# cloud_cover           2853
# moon_phase            3156
# precip_intensity      2493
# precip_probability    2493
# precip_type           1560
# pressure              2411
# summary               3156
# uv_index              3156
# visibility            2817
# wind_bearing          3147
# wind_speed            3149
# dtype: int64

# %%
# Begin filtering data
bf_geo_cols = ['observed', 'county', 'state', 'latitude', 'longitude', 'date','number', 'classification']
bf_geo_transformed = bigfoot_geo_df[bf_geo_cols].copy()

# Drop null values on 'number'
bf_geo_transformed = bf_geo_transformed[bf_geo_transformed['number'].notna()]

bf_geo_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                            county          state  latitude  longitude  \
# 0  Valdez-Chitina-Whittier County         Alaska       NaN        NaN
# 1                   Warren County     New Jersey       NaN        NaN
# 2                 Sullivan County  New Hampshire  43.41549  -72.33093
# 3                 Thurston County       Nebraska  42.15685  -96.34203
# 4                     Ward County   North Dakota  48.25422 -101.31660
#
#          date   number classification
# 0         NaN   1261.0        Class A
# 1         NaN    438.0        Class B
# 2  2016-06-07  55269.0        Class A
# 3  2018-05-25  59757.0        Class B
# 4  2000-04-21    751.0        Class A

# %%
bfro_rep_df.head()
# Out:
#            YEAR  SEASON          STATE                          COUNTY  \
# 0  Early 1990's    Fall         Alaska  Valdez-Chitina-Whittier County
# 1           NaN     NaN            NaN                             NaN
# 2          2000    Fall     New Jersey                   Warren County
# 3          2016  Summer  New Hampshire                 Sullivan County
# 4          2018  Spring       Nebraska                 Thurston County
#
#                                     LOCATION_DETAILS  \
# 0                  East side of Prince William Sound
# 1                                                NaN
# 2  the road is off us rt 80, i dont know the exit...
# 3  Close to Claremont down 120 not far from Kings...
# 4      Latitude & Longitude :  42.158230  -96.344197
#
#                                             OBSERVED  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1                                                NaN
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
#
#                                      OTHER_WITNESSES  \
# 0  On a commercial fishing boat at anchor at the ...
# 1                                                NaN
# 2  my friend was asleep, and i was lying next to ...
# 3                                        Just myself
# 4  2 witnesses saw the creature. 3 people were pr...
#
#                                  TIME_AND_CONDITIONS  REPORT_NUMBER  \
# 0                   Early Fall, in the early 1990's.         1261.0
# 1                                                NaN            NaN
# 2  lighting was from a camp fire that was dieing ...          438.0
# 3                           5am. Dawn. Clear weather        55269.0
# 4  1:35 pm on a clear and very hot sunny day. Tem...        59757.0
#
#   REPORT_CLASS      MONTH        DATE NEAREST_TOWN          NEAREST_ROAD  \
# 0      Class A        NaN         NaN          NaN                   NaN
# 1         None        NaN         NaN          NaN                   NaN
# 2      Class B  September  2nd or 3rd    Allumuchy  not sure of the road
# 3      Class A       June           7    Claremont               Rte 120
# 4      Class B        May          25         Macy           Highway 201
#
#                                         ALSO_NOTICED  \
# 0                                                NaN
# 1                                                NaN
# 2                                            nothing
# 3                                                NaN
# 4  I had audio recorders set up in the area and r...
#
#                                        OTHER_STORIES  \
# 0                                                NaN
# 1                                                NaN
# 2  no but after the events stated i looked at you...
# 3                                                NaN
# 4  There are MANY encounters in this general area...
#
#                                          ENVIRONMENT A_&_G_References
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  good size river, steep hills, very rugged area...              NaN
# 3  swamp with forest behind it. There was a large...              NaN
# 4  This is a heavily forested area bordering the ...              NaN

# %%
# Begin filtering json data
bf_reports_cols = ['OBSERVED', 'COUNTY', 'STATE', 'REPORT_NUMBER', 'REPORT_CLASS']
bf_reports_transformed = bfro_rep_df[bf_reports_cols].copy()

# Rename column headers
bf_reports_transformed = bf_reports_transformed.rename(columns={"OBSERVED": 'observed',
                                                               'COUNTY': 'county',
                                                               'STATE': 'state',
                                                               'REPORT_NUMBER': 'number',
                                                               'REPORT_CLASS': 'classification'})

# Drop null values on 'number'
bf_reports_transformed = bf_reports_transformed[bf_reports_transformed['number'].notna()]

bf_reports_transformed.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 2  heh i kinda feel a little dumb that im reporti...
# 3  I was on my way to Claremont from Lebanon on R...
# 4  I was northeast of Macy Nebraska along the Mis...
# 5  While this incident occurred a long time ago, ...
#
#                            county          state   number classification
# 0  Valdez-Chitina-Whittier County         Alaska   1261.0        Class A
# 2                   Warren County     New Jersey    438.0        Class B
# 3                 Sullivan County  New Hampshire  55269.0        Class A
# 4                 Thurston County       Nebraska  59757.0        Class B
# 5                     Ward County   North Dakota    751.0        Class A

# %%
bf_reports_transformed.count()
# Out:
# observed          4711
# county            4747
# state             4747
# number            4747
# classification    4747
# dtype: int64

# %%
# Merge bf_geo_transformed and bf_reports_transformed DataFrames
bf_merge = pd.merge(bf_geo_transformed, bf_reports_transformed, on='number', how='outer', suffixes=("_geocoded", "_reports"))
bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4742  My cousin and I were camping way out in the wo...
# 4743  While backpacking near the horse trails and ac...
# 4744  My wife and I were camping At Yellowood State ...
# 4745  My wife and I were driving to Indianapolis to ...
# 4746  It was about 7:00 PM in September. It was stil...
#
#                      county_geocoded state_geocoded  latitude  longitude  \
# 0     Valdez-Chitina-Whittier County         Alaska       NaN        NaN
# 1                      Warren County     New Jersey       NaN        NaN
# 2                    Sullivan County  New Hampshire  43.41549  -72.33093
# 3                    Thurston County       Nebraska  42.15685  -96.34203
# 4                        Ward County   North Dakota  48.25422 -101.31660
# ...                              ...            ...       ...        ...
# 4742                    Brown County        Indiana       NaN        NaN
# 4743                    Brown County        Indiana       NaN        NaN
# 4744                    Brown County        Indiana  39.17909  -86.33560
# 4745                    Boone County        Indiana       NaN        NaN
# 4746                Blackford County        Indiana       NaN        NaN
#
#             date   number classification_geocoded  \
# 0            NaN   1261.0                 Class A
# 1            NaN    438.0                 Class B
# 2     2016-06-07  55269.0                 Class A
# 3     2018-05-25  59757.0                 Class B
# 4     2000-04-21    751.0                 Class A
# ...          ...      ...                     ...
# 4742         NaN   2460.0                 Class B
# 4743         NaN   2461.0                 Class A
# 4744  2015-08-08  49480.0                 Class B
# 4745         NaN   2459.0                 Class A
# 4746         NaN   2458.0                 Class B
#
#                                        observed_reports  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4742  My cousin and I were camping way out in the wo...
# 4743  While backpacking near the horse trails and ac...
# 4744  My wife and I were camping At Yellowood State ...
# 4745  My wife and I were driving to Indianapolis to ...
# 4746  It was about 7:00 PM in September. It was stil...
#
#                       county_reports  state_reports classification_reports
# 0     Valdez-Chitina-Whittier County         Alaska                Class A
# 1                      Warren County     New Jersey                Class B
# 2                    Sullivan County  New Hampshire                Class A
# 3                    Thurston County       Nebraska                Class B
# 4                        Ward County   North Dakota                Class A
# ...                              ...            ...                    ...
# 4742                    Brown County        Indiana                Class B
# 4743                    Brown County        Indiana                Class A
# 4744                    Brown County        Indiana                Class B
# 4745                    Boone County        Indiana                Class A
# 4746                Blackford County        Indiana                Class B
#
# [4747 rows x 12 columns]

# %%
# check to see if values from separate datasets match
# checking observation
bf_merge[bf_merge['observed_geocoded']!=bf_merge['observed_reports']]
# Out:
#      observed_geocoded       county_geocoded state_geocoded  latitude  \
# 191                NaN         Oscoda County       Michigan  44.68000
# 261                NaN        Midland County       Michigan  43.79834
# 268                NaN         Ingham County       Michigan  42.75195
# 293                NaN      Dickinson County       Michigan  46.01398
# 395                NaN         Itasca County      Minnesota  47.52522
# 480                NaN        Pulaski County       Missouri  37.79250
# 555                NaN       Marshall County    Mississippi       NaN
# 907                NaN         Putnam County       New York  41.38084
# 913                NaN        Steuben County       New York  42.28045
# 1009               NaN          Stark County           Ohio  40.75872
# 1053               NaN         Morrow County           Ohio  40.38609
# 1154               NaN       Guernsey County           Ohio  40.10801
# 1308               NaN       Le Flore County       Oklahoma  34.84167
# 1632               NaN     Clearfield County   Pennsylvania  41.01865
# 1656               NaN      Jefferson County   Pennsylvania       NaN
# 1768               NaN         Monroe County      Tennessee  35.25970
# 2079               NaN         Summit County           Utah  40.82500
# 2279               NaN         Pierce County     Washington  47.18556
# 2417               NaN      Snohomish County     Washington  48.09853
# 3122               NaN         Valley County          Idaho  44.66862
# 3134               NaN      Talladega County        Alabama  33.36305
# 3164               NaN        Lowndes County        Alabama  32.18400
# 3474               NaN  Santa Barbara County     California  34.73389
# 3500               NaN           Mono County     California  38.29165
# 3579               NaN         Shasta County     California  40.79740
# 3680               NaN      El Dorado County     California  38.93333
# 3727               NaN       Humboldt County     California  40.85000
# 3812               NaN        Larimer County       Colorado       NaN
# 4074               NaN       Hernando County        Florida  28.57160
# 4137               NaN          Wayne County        Georgia  31.46641
# 4145               NaN          White County        Georgia       NaN
# 4240               NaN       Paulding County        Georgia  33.81283
# 4268               NaN         Jasper County        Georgia  33.46372
# 4399               NaN         Cassia County          Idaho       NaN
# 4421               NaN         Bonner County          Idaho  48.33000
# 4684               NaN        Warrick County        Indiana  38.01000
#
#       longitude        date   number classification_geocoded observed_reports  \
# 191   -84.01165  2013-03-12  40106.0                 Class B              NaN
# 261   -84.21140  1972-11-15   2830.0                 Class A              NaN
# 268   -81.52805  2015-04-01  49621.0                 Class B              NaN
# 293   -87.98718  1965-07-01  20002.0                 Class A              NaN
# 395   -93.25262  1970-11-01  28711.0                 Class A              NaN
# 480   -92.05000  2017-07-08  62393.0                 Class A              NaN
# 555         NaN         NaN  27167.0                 Class A              NaN
# 907   -73.91649  2004-09-20  15144.0                 Class B              NaN
# 913   -77.60525  1980-04-21  13662.0                 Class A              NaN
# 1009  -81.19895  1992-01-15   5030.0                 Class A              NaN
# 1053  -82.69884  1977-06-01   1625.0                 Class A              NaN
# 1154  -81.56232  2003-05-15  24141.0                 Class A              NaN
# 1308  -94.63111  2001-03-20   1966.0                 Class B              NaN
# 1632  -78.37700  1921-01-14  14358.0                 Class A             None
# 1656        NaN         NaN  44350.0                 Class B              NaN
# 1768  -84.28315  2000-08-03   3008.0                 Class A              NaN
# 2079 -110.82500  2001-06-13  18056.0                 Class B              NaN
# 2279 -122.29170  1974-06-27  10653.0                 Class A              NaN
# 2417 -121.81350  1989-06-01  44368.0                 Class A              NaN
# 3122 -116.11550  2018-11-21  62182.0                 Class A              NaN
# 3134  -86.17122  1999-11-23  25238.0                 Class A              NaN
# 3164  -86.58100  2001-04-13  24646.0                 Class A              NaN
# 3474 -119.92540  1982-04-15  25444.0                 Class A              NaN
# 3500 -119.54000  1980-08-01  13613.0                 Class B              NaN
# 3579 -122.27800  2001-03-15  11986.0                 Class A              NaN
# 3680 -119.98330  1996-04-10    919.0                 Class A              NaN
# 3727 -123.55000  1988-10-15  11576.0                 Class A              NaN
# 3812        NaN         NaN  57114.0                 Class B              NaN
# 4074  -82.52655  2004-02-17   6708.0                 Class A              NaN
# 4137  -81.64665  2008-11-23  27072.0                 Class A              NaN
# 4145        NaN         NaN  22852.0                 Class B              NaN
# 4240  -84.80283  2006-07-05  14887.0                 Class B              NaN
# 4268  -83.61285  1986-06-15  33115.0                 Class A              NaN
# 4399        NaN         NaN   3629.0                 Class A              NaN
# 4421 -116.71000  2008-08-19  24693.0                 Class B              NaN
# 4684  -87.32030  1937-08-16  14336.0                 Class A             None
#
#             county_reports state_reports classification_reports
# 191          Oscoda County      Michigan                Class B
# 261         Midland County      Michigan                Class A
# 268          Ingham County      Michigan                Class B
# 293       Dickinson County      Michigan                Class A
# 395          Itasca County     Minnesota                Class A
# 480         Pulaski County      Missouri                Class A
# 555        Marshall County   Mississippi                Class A
# 907          Putnam County      New York                Class B
# 913         Steuben County      New York                Class A
# 1009          Stark County          Ohio                Class A
# 1053         Morrow County          Ohio                Class A
# 1154       Guernsey County          Ohio                Class A
# 1308       Le Flore County      Oklahoma                Class B
# 1632     Clearfield County  Pennsylvania                Class A
# 1656      Jefferson County  Pennsylvania                Class B
# 1768         Monroe County     Tennessee                Class A
# 2079         Summit County          Utah                Class B
# 2279         Pierce County    Washington                Class A
# 2417      Snohomish County    Washington                Class A
# 3122         Valley County         Idaho                Class A
# 3134      Talladega County       Alabama                Class A
# 3164        Lowndes County       Alabama                Class A
# 3474  Santa Barbara County    California                Class A
# 3500           Mono County    California                Class B
# 3579         Shasta County    California                Class A
# 3680      El Dorado County    California                Class A
# 3727       Humboldt County    California                Class A
# 3812        Larimer County      Colorado                Class B
# 4074       Hernando County       Florida                Class A
# 4137          Wayne County       Georgia                Class A
# 4145          White County       Georgia                Class B
# 4240       Paulding County       Georgia                Class B
# 4268         Jasper County       Georgia                Class A
# 4399         Cassia County         Idaho                Class A
# 4421         Bonner County         Idaho                Class B
# 4684        Warrick County       Indiana                Class A

# %%
# Final merge with bf_loc_transformed into DataFrame and drop na
final_bf_merge = pd.merge(bf_merge, bf_loc_transformed, on='number', how='outer', suffixes=("_reports", "_location"))

final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#                                        observed_reports  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                       county_reports  state_reports classification_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska                Class A
# 1                      Warren County     New Jersey                Class B
# 2                    Sullivan County  New Hampshire                Class A
# 3                    Thurston County       Nebraska                Class B
# 4                        Ward County   North Dakota                Class A
# ...                              ...            ...                    ...
# 4929                             NaN            NaN                    NaN
# 4930                             NaN            NaN                    NaN
# 4931                             NaN            NaN                    NaN
# 4932                             NaN            NaN                    NaN
# 4933                             NaN            NaN                    NaN
#
#      classification             timestamp  latitude_location  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2           Class A  2016-06-07T12:00:00Z           43.41549
# 3           Class B  2018-05-25T12:00:00Z           42.15685
# 4           Class A  2000-04-21T12:00:00Z           48.25422
# ...             ...                   ...                ...
# 4929        Class B  2017-10-30T12:00:00Z           42.36689
# 4930        Class B  2004-07-01T12:00:00Z           38.49710
# 4931        Class C  1996-04-15T12:00:00Z           33.94175
# 4932        Class C  2004-09-15T12:00:00Z           28.21492
# 4933        Class C  1986-04-15T12:00:00Z           33.49960
#
#       longitude_location
# 0                    NaN
# 1                    NaN
# 2              -72.33093
# 3              -96.34203
# 4             -101.31660
# ...                  ...
# 4929           -73.18228
# 4930           -90.72120
# 4931           -86.17965
# 4932           -82.45240
# 4933           -84.54220
#
# [4934 rows x 16 columns]

# %%
# Split timestamp column into date and time column
final_bf_merge[['Date_loc','Time']] = final_bf_merge.timestamp.str.split("T",expand=True)
final_bf_merge = final_bf_merge.drop(['timestamp', 'Time'], axis=1)
final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#                                        observed_reports  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                       county_reports  state_reports classification_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska                Class A
# 1                      Warren County     New Jersey                Class B
# 2                    Sullivan County  New Hampshire                Class A
# 3                    Thurston County       Nebraska                Class B
# 4                        Ward County   North Dakota                Class A
# ...                              ...            ...                    ...
# 4929                             NaN            NaN                    NaN
# 4930                             NaN            NaN                    NaN
# 4931                             NaN            NaN                    NaN
# 4932                             NaN            NaN                    NaN
# 4933                             NaN            NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 0               NaN                NaN                 NaN         NaN
# 1               NaN                NaN                 NaN         NaN
# 2           Class A           43.41549           -72.33093  2016-06-07
# 3           Class B           42.15685           -96.34203  2018-05-25
# 4           Class A           48.25422          -101.31660  2000-04-21
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [4934 rows x 16 columns]

# %%
# check to see if values from separate datasets match
# checking date
final_bf_merge[final_bf_merge['date']!=final_bf_merge['Date_loc']]
# not dropping either date column because the values differ
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 9     I was bowhunting and just sitting in my stand ...
# 11    In the spring of 1974 my girlfriend and I were...
# 12    In September of 1997 while traveling north on ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 9                  Washington County      Minnesota               NaN
# 11                       York County          Maine               NaN
# 12                  Worcester County       Maryland               NaN
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded  \
# 0                   NaN  NaN   1261.0                 Class A
# 1                   NaN  NaN    438.0                 Class B
# 9                   NaN  NaN   1081.0                 Class A
# 11                  NaN  NaN    883.0                 Class B
# 12                  NaN  NaN   8135.0                 Class A
# ...                 ...  ...      ...                     ...
# 4929                NaN  NaN  58445.0                     NaN
# 4930                NaN  NaN  10445.0                     NaN
# 4931                NaN  NaN    483.0                     NaN
# 4932                NaN  NaN  25381.0                     NaN
# 4933                NaN  NaN    444.0                     NaN
#
#                                        observed_reports  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 9     I was bowhunting and just sitting in my stand ...
# 11    In the spring of 1974 my girlfriend and I were...
# 12    In September of 1997 while traveling north on ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                       county_reports state_reports classification_reports  \
# 0     Valdez-Chitina-Whittier County        Alaska                Class A
# 1                      Warren County    New Jersey                Class B
# 9                  Washington County     Minnesota                Class A
# 11                       York County         Maine                Class B
# 12                  Worcester County      Maryland                Class A
# ...                              ...           ...                    ...
# 4929                             NaN           NaN                    NaN
# 4930                             NaN           NaN                    NaN
# 4931                             NaN           NaN                    NaN
# 4932                             NaN           NaN                    NaN
# 4933                             NaN           NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 0               NaN                NaN                 NaN         NaN
# 1               NaN                NaN                 NaN         NaN
# 9               NaN                NaN                 NaN         NaN
# 11              NaN                NaN                 NaN         NaN
# 12              NaN                NaN                 NaN         NaN
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [1137 rows x 16 columns]

# %%
# check to see if values from separate datasets match
# checking observed
final_bf_merge[final_bf_merge['observed_geocoded']!=final_bf_merge['observed_reports']]
# Out:
#      observed_geocoded   county_geocoded state_geocoded  latitude_reports  \
# 191                NaN     Oscoda County       Michigan          44.68000
# 261                NaN    Midland County       Michigan          43.79834
# 268                NaN     Ingham County       Michigan          42.75195
# 293                NaN  Dickinson County       Michigan          46.01398
# 395                NaN     Itasca County      Minnesota          47.52522
# ...                ...               ...            ...               ...
# 4929               NaN               NaN            NaN               NaN
# 4930               NaN               NaN            NaN               NaN
# 4931               NaN               NaN            NaN               NaN
# 4932               NaN               NaN            NaN               NaN
# 4933               NaN               NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 191           -84.01165  2013-03-12  40106.0                 Class B
# 261           -84.21140  1972-11-15   2830.0                 Class A
# 268           -81.52805  2015-04-01  49621.0                 Class B
# 293           -87.98718  1965-07-01  20002.0                 Class A
# 395           -93.25262  1970-11-01  28711.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      observed_reports    county_reports state_reports classification_reports  \
# 191               NaN     Oscoda County      Michigan                Class B
# 261               NaN    Midland County      Michigan                Class A
# 268               NaN     Ingham County      Michigan                Class B
# 293               NaN  Dickinson County      Michigan                Class A
# 395               NaN     Itasca County     Minnesota                Class A
# ...               ...               ...           ...                    ...
# 4929              NaN               NaN           NaN                    NaN
# 4930              NaN               NaN           NaN                    NaN
# 4931              NaN               NaN           NaN                    NaN
# 4932              NaN               NaN           NaN                    NaN
# 4933              NaN               NaN           NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 191         Class B           44.68000           -84.01165  2013-03-12
# 261         Class A           43.79834           -84.21140  1972-11-15
# 268         Class B           42.75195           -81.52805  2015-04-01
# 293         Class A           46.01398           -87.98718  1965-07-01
# 395         Class A           47.52522           -93.25262  1970-11-01
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [223 rows x 16 columns]

# %%
# dropping observed column, because values match
final_bf_merge = final_bf_merge.drop(['observed_reports'], axis=1)
final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#                       county_reports  state_reports classification_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska                Class A
# 1                      Warren County     New Jersey                Class B
# 2                    Sullivan County  New Hampshire                Class A
# 3                    Thurston County       Nebraska                Class B
# 4                        Ward County   North Dakota                Class A
# ...                              ...            ...                    ...
# 4929                             NaN            NaN                    NaN
# 4930                             NaN            NaN                    NaN
# 4931                             NaN            NaN                    NaN
# 4932                             NaN            NaN                    NaN
# 4933                             NaN            NaN                    NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 0               NaN                NaN                 NaN         NaN
# 1               NaN                NaN                 NaN         NaN
# 2           Class A           43.41549           -72.33093  2016-06-07
# 3           Class B           42.15685           -96.34203  2018-05-25
# 4           Class A           48.25422          -101.31660  2000-04-21
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [4934 rows x 15 columns]

# %%
# check to see if values from separate datasets match
# checking county
final_bf_merge[final_bf_merge['county_geocoded']!=final_bf_merge['county_reports']]
# Out:
#      observed_geocoded county_geocoded state_geocoded  latitude_reports  \
# 4747               NaN             NaN            NaN               NaN
# 4748               NaN             NaN            NaN               NaN
# 4749               NaN             NaN            NaN               NaN
# 4750               NaN             NaN            NaN               NaN
# 4751               NaN             NaN            NaN               NaN
# ...                ...             ...            ...               ...
# 4929               NaN             NaN            NaN               NaN
# 4930               NaN             NaN            NaN               NaN
# 4931               NaN             NaN            NaN               NaN
# 4932               NaN             NaN            NaN               NaN
# 4933               NaN             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded county_reports  \
# 4747                NaN  NaN    211.0                     NaN            NaN
# 4748                NaN  NaN   9876.0                     NaN            NaN
# 4749                NaN  NaN  10775.0                     NaN            NaN
# 4750                NaN  NaN  12001.0                     NaN            NaN
# 4751                NaN  NaN  12647.0                     NaN            NaN
# ...                 ...  ...      ...                     ...            ...
# 4929                NaN  NaN  58445.0                     NaN            NaN
# 4930                NaN  NaN  10445.0                     NaN            NaN
# 4931                NaN  NaN    483.0                     NaN            NaN
# 4932                NaN  NaN  25381.0                     NaN            NaN
# 4933                NaN  NaN    444.0                     NaN            NaN
#
#      state_reports classification_reports classification  latitude_location  \
# 4747           NaN                    NaN        Class A           50.40230
# 4748           NaN                    NaN        Class A           50.08650
# 4749           NaN                    NaN        Class A           55.26332
# 4750           NaN                    NaN        Class A           53.62819
# 4751           NaN                    NaN        Class A           52.51666
# ...            ...                    ...            ...                ...
# 4929           NaN                    NaN        Class B           42.36689
# 4930           NaN                    NaN        Class B           38.49710
# 4931           NaN                    NaN        Class C           33.94175
# 4932           NaN                    NaN        Class C           28.21492
# 4933           NaN                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 4747          -114.44190  1995-11-18
# 4748          -114.23470  2003-11-15
# 4749          -114.39570  1976-02-12
# 4750          -114.13970  2005-04-15
# 4751          -115.87420  1998-06-30
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [187 rows x 15 columns]

# %%
# dropping county column, because values match
final_bf_merge = final_bf_merge.drop(['county_reports'], axis=1)
final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#       state_reports classification_reports classification  latitude_location  \
# 0            Alaska                Class A            NaN                NaN
# 1        New Jersey                Class B            NaN                NaN
# 2     New Hampshire                Class A        Class A           43.41549
# 3          Nebraska                Class B        Class B           42.15685
# 4      North Dakota                Class A        Class A           48.25422
# ...             ...                    ...            ...                ...
# 4929            NaN                    NaN        Class B           42.36689
# 4930            NaN                    NaN        Class B           38.49710
# 4931            NaN                    NaN        Class C           33.94175
# 4932            NaN                    NaN        Class C           28.21492
# 4933            NaN                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2              -72.33093  2016-06-07
# 3              -96.34203  2018-05-25
# 4             -101.31660  2000-04-21
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [4934 rows x 14 columns]

# %%
# check to see if values from separate datasets match
# checking state
final_bf_merge[final_bf_merge['state_geocoded']!=final_bf_merge['state_reports']]
# Out:
#      observed_geocoded county_geocoded state_geocoded  latitude_reports  \
# 4747               NaN             NaN            NaN               NaN
# 4748               NaN             NaN            NaN               NaN
# 4749               NaN             NaN            NaN               NaN
# 4750               NaN             NaN            NaN               NaN
# 4751               NaN             NaN            NaN               NaN
# ...                ...             ...            ...               ...
# 4929               NaN             NaN            NaN               NaN
# 4930               NaN             NaN            NaN               NaN
# 4931               NaN             NaN            NaN               NaN
# 4932               NaN             NaN            NaN               NaN
# 4933               NaN             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded state_reports  \
# 4747                NaN  NaN    211.0                     NaN           NaN
# 4748                NaN  NaN   9876.0                     NaN           NaN
# 4749                NaN  NaN  10775.0                     NaN           NaN
# 4750                NaN  NaN  12001.0                     NaN           NaN
# 4751                NaN  NaN  12647.0                     NaN           NaN
# ...                 ...  ...      ...                     ...           ...
# 4929                NaN  NaN  58445.0                     NaN           NaN
# 4930                NaN  NaN  10445.0                     NaN           NaN
# 4931                NaN  NaN    483.0                     NaN           NaN
# 4932                NaN  NaN  25381.0                     NaN           NaN
# 4933                NaN  NaN    444.0                     NaN           NaN
#
#      classification_reports classification  latitude_location  \
# 4747                    NaN        Class A           50.40230
# 4748                    NaN        Class A           50.08650
# 4749                    NaN        Class A           55.26332
# 4750                    NaN        Class A           53.62819
# 4751                    NaN        Class A           52.51666
# ...                     ...            ...                ...
# 4929                    NaN        Class B           42.36689
# 4930                    NaN        Class B           38.49710
# 4931                    NaN        Class C           33.94175
# 4932                    NaN        Class C           28.21492
# 4933                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 4747          -114.44190  1995-11-18
# 4748          -114.23470  2003-11-15
# 4749          -114.39570  1976-02-12
# 4750          -114.13970  2005-04-15
# 4751          -115.87420  1998-06-30
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [187 rows x 14 columns]

# %%
# dropping observed column, because values match
final_bf_merge = final_bf_merge.drop(['state_reports'], axis=1)
final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      classification_reports classification  latitude_location  \
# 0                   Class A            NaN                NaN
# 1                   Class B            NaN                NaN
# 2                   Class A        Class A           43.41549
# 3                   Class B        Class B           42.15685
# 4                   Class A        Class A           48.25422
# ...                     ...            ...                ...
# 4929                    NaN        Class B           42.36689
# 4930                    NaN        Class B           38.49710
# 4931                    NaN        Class C           33.94175
# 4932                    NaN        Class C           28.21492
# 4933                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2              -72.33093  2016-06-07
# 3              -96.34203  2018-05-25
# 4             -101.31660  2000-04-21
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [4934 rows x 13 columns]

# %%
# check to see if values from separate datasets match
# checking latitude
final_bf_merge[final_bf_merge['latitude_reports']!=final_bf_merge['latitude_location']]
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 4     While this incident occurred a long time ago, ...
# 8     i want to start this off by saying, I don't kn...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 4                        Ward County   North Dakota          48.25422
# 8                      Wright County       Missouri          37.46041
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 4            -101.31660  2000-04-21    751.0                 Class A
# 8             -92.63587  2018-04-14  59307.0                 Class B
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      classification_reports classification  latitude_location  \
# 0                   Class A            NaN                NaN
# 1                   Class B            NaN                NaN
# 2                   Class A        Class A           43.41549
# 4                   Class A        Class A           48.25422
# 8                   Class B        Class B           37.46041
# ...                     ...            ...                ...
# 4929                    NaN        Class B           42.36689
# 4930                    NaN        Class B           38.49710
# 4931                    NaN        Class C           33.94175
# 4932                    NaN        Class C           28.21492
# 4933                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2              -72.33093  2016-06-07
# 4             -101.31660  2000-04-21
# 8              -92.63587  2018-04-14
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [1598 rows x 13 columns]

# %%
# check to see if values from separate datasets match
# checking longitude
final_bf_merge[final_bf_merge['longitude_reports']!=final_bf_merge['longitude_location']]
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 9     I was bowhunting and just sitting in my stand ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 9                  Washington County      Minnesota               NaN
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 9                   NaN         NaN   1081.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      classification_reports classification  latitude_location  \
# 0                   Class A            NaN                NaN
# 1                   Class B            NaN                NaN
# 2                   Class A        Class A           43.41549
# 3                   Class B        Class B           42.15685
# 9                   Class A            NaN                NaN
# ...                     ...            ...                ...
# 4929                    NaN        Class B           42.36689
# 4930                    NaN        Class B           38.49710
# 4931                    NaN        Class C           33.94175
# 4932                    NaN        Class C           28.21492
# 4933                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2              -72.33093  2016-06-07
# 3              -96.34203  2018-05-25
# 9                    NaN         NaN
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [1519 rows x 13 columns]

# %%
# check to see if values from separate datasets match
# checking classification
final_bf_merge[final_bf_merge['classification_geocoded']!=final_bf_merge['classification_reports']]
# Out:
#      observed_geocoded county_geocoded state_geocoded  latitude_reports  \
# 4747               NaN             NaN            NaN               NaN
# 4748               NaN             NaN            NaN               NaN
# 4749               NaN             NaN            NaN               NaN
# 4750               NaN             NaN            NaN               NaN
# 4751               NaN             NaN            NaN               NaN
# ...                ...             ...            ...               ...
# 4929               NaN             NaN            NaN               NaN
# 4930               NaN             NaN            NaN               NaN
# 4931               NaN             NaN            NaN               NaN
# 4932               NaN             NaN            NaN               NaN
# 4933               NaN             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded  \
# 4747                NaN  NaN    211.0                     NaN
# 4748                NaN  NaN   9876.0                     NaN
# 4749                NaN  NaN  10775.0                     NaN
# 4750                NaN  NaN  12001.0                     NaN
# 4751                NaN  NaN  12647.0                     NaN
# ...                 ...  ...      ...                     ...
# 4929                NaN  NaN  58445.0                     NaN
# 4930                NaN  NaN  10445.0                     NaN
# 4931                NaN  NaN    483.0                     NaN
# 4932                NaN  NaN  25381.0                     NaN
# 4933                NaN  NaN    444.0                     NaN
#
#      classification_reports classification  latitude_location  \
# 4747                    NaN        Class A           50.40230
# 4748                    NaN        Class A           50.08650
# 4749                    NaN        Class A           55.26332
# 4750                    NaN        Class A           53.62819
# 4751                    NaN        Class A           52.51666
# ...                     ...            ...                ...
# 4929                    NaN        Class B           42.36689
# 4930                    NaN        Class B           38.49710
# 4931                    NaN        Class C           33.94175
# 4932                    NaN        Class C           28.21492
# 4933                    NaN        Class C           33.49960
#
#       longitude_location    Date_loc
# 4747          -114.44190  1995-11-18
# 4748          -114.23470  2003-11-15
# 4749          -114.39570  1976-02-12
# 4750          -114.13970  2005-04-15
# 4751          -115.87420  1998-06-30
# ...                  ...         ...
# 4929           -73.18228  2017-10-30
# 4930           -90.72120  2004-07-01
# 4931           -86.17965  1996-04-15
# 4932           -82.45240  2004-09-15
# 4933           -84.54220  1986-04-15
#
# [187 rows x 13 columns]

# %%
# dropping classification_reports column, because values match
final_bf_merge = final_bf_merge.drop(['classification_reports'], axis=1)
final_bf_merge
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports        date   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 0               NaN                NaN                 NaN         NaN
# 1               NaN                NaN                 NaN         NaN
# 2           Class A           43.41549           -72.33093  2016-06-07
# 3           Class B           42.15685           -96.34203  2018-05-25
# 4           Class A           48.25422          -101.31660  2000-04-21
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [4934 rows x 12 columns]

# %%
# check to see if values from separate datasets match
# checking classification
final_bf_merge[final_bf_merge['classification_geocoded']!=final_bf_merge['classification']]
# Out:
#                                       observed_geocoded  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 9     I was bowhunting and just sitting in my stand ...
# 11    In the spring of 1974 my girlfriend and I were...
# 12    In September of 1997 while traveling north on ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                      county_geocoded state_geocoded  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 9                  Washington County      Minnesota               NaN
# 11                       York County          Maine               NaN
# 12                  Worcester County       Maryland               NaN
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports date   number classification_geocoded classification  \
# 0                   NaN  NaN   1261.0                 Class A            NaN
# 1                   NaN  NaN    438.0                 Class B            NaN
# 9                   NaN  NaN   1081.0                 Class A            NaN
# 11                  NaN  NaN    883.0                 Class B            NaN
# 12                  NaN  NaN   8135.0                 Class A            NaN
# ...                 ...  ...      ...                     ...            ...
# 4929                NaN  NaN  58445.0                     NaN        Class B
# 4930                NaN  NaN  10445.0                     NaN        Class B
# 4931                NaN  NaN    483.0                     NaN        Class C
# 4932                NaN  NaN  25381.0                     NaN        Class C
# 4933                NaN  NaN    444.0                     NaN        Class C
#
#       latitude_location  longitude_location    Date_loc
# 0                   NaN                 NaN         NaN
# 1                   NaN                 NaN         NaN
# 9                   NaN                 NaN         NaN
# 11                  NaN                 NaN         NaN
# 12                  NaN                 NaN         NaN
# ...                 ...                 ...         ...
# 4929           42.36689           -73.18228  2017-10-30
# 4930           38.49710           -90.72120  2004-07-01
# 4931           33.94175           -86.17965  1996-04-15
# 4932           28.21492           -82.45240  2004-09-15
# 4933           33.49960           -84.54220  1986-04-15
#
# [1127 rows x 12 columns]

# %%
# Rename column headers
final_bf_merge = final_bf_merge.rename(columns={"observed_geocoded": 'observed',
                                                'county_geocoded': 'county',
                                                'state_geocoded': 'state',
                                                'date': 'date_geo',
                                               })
final_bf_merge
# Out:
#                                                observed  \
# 0     Ed L. was salmon fishing with a companion in P...
# 1     heh i kinda feel a little dumb that im reporti...
# 2     I was on my way to Claremont from Lebanon on R...
# 3     I was northeast of Macy Nebraska along the Mis...
# 4     While this incident occurred a long time ago, ...
# ...                                                 ...
# 4929                                                NaN
# 4930                                                NaN
# 4931                                                NaN
# 4932                                                NaN
# 4933                                                NaN
#
#                               county          state  latitude_reports  \
# 0     Valdez-Chitina-Whittier County         Alaska               NaN
# 1                      Warren County     New Jersey               NaN
# 2                    Sullivan County  New Hampshire          43.41549
# 3                    Thurston County       Nebraska          42.15685
# 4                        Ward County   North Dakota          48.25422
# ...                              ...            ...               ...
# 4929                             NaN            NaN               NaN
# 4930                             NaN            NaN               NaN
# 4931                             NaN            NaN               NaN
# 4932                             NaN            NaN               NaN
# 4933                             NaN            NaN               NaN
#
#       longitude_reports    date_geo   number classification_geocoded  \
# 0                   NaN         NaN   1261.0                 Class A
# 1                   NaN         NaN    438.0                 Class B
# 2             -72.33093  2016-06-07  55269.0                 Class A
# 3             -96.34203  2018-05-25  59757.0                 Class B
# 4            -101.31660  2000-04-21    751.0                 Class A
# ...                 ...         ...      ...                     ...
# 4929                NaN         NaN  58445.0                     NaN
# 4930                NaN         NaN  10445.0                     NaN
# 4931                NaN         NaN    483.0                     NaN
# 4932                NaN         NaN  25381.0                     NaN
# 4933                NaN         NaN    444.0                     NaN
#
#      classification  latitude_location  longitude_location    Date_loc
# 0               NaN                NaN                 NaN         NaN
# 1               NaN                NaN                 NaN         NaN
# 2           Class A           43.41549           -72.33093  2016-06-07
# 3           Class B           42.15685           -96.34203  2018-05-25
# 4           Class A           48.25422          -101.31660  2000-04-21
# ...             ...                ...                 ...         ...
# 4929        Class B           42.36689           -73.18228  2017-10-30
# 4930        Class B           38.49710           -90.72120  2004-07-01
# 4931        Class C           33.94175           -86.17965  1996-04-15
# 4932        Class C           28.21492           -82.45240  2004-09-15
# 4933        Class C           33.49960           -84.54220  1986-04-15
#
# [4934 rows x 12 columns]

# %%
# List of columns from dataframes

bigfoot_locations_df.head()
list_loc=[]
for col in bigfoot_locations_df.columns: 
    list_loc.append(col)

# %%
# Bigfoot_geo_df.head()
list_geo=[]
for col in bigfoot_geo_df.columns: 
    list_geo.append(col)

# %%
inter=intersection(list_geo, list_loc)

# %%
bf_geo=bigfoot_geo_df[inter]
bf_geo=bf_geo[['number','title','classification','latitude','longitude']]

#final=pd.concat([ye,bigfoot_locations_df])

# %%
#bfro_rep_df.head()

geo_nums=bf_geo_transformed['number'].tolist()
loc_nums=bigfoot_locations_df['number'].tolist()
intr_nums=intersection(geo_nums,loc_nums)
print(len(geo_nums))
print(len(loc_nums))
print(len(intr_nums))

# %%
# sanity check
for loc in loc_nums:
    if loc not in geo_nums:
        print(loc)

# %%
# another sanity check
report_nums = bf_reports_transformed['number'].tolist()
inter_nums = intersection(report_nums,geo_nums) 
print(len(inter_nums))

# %% [markdown]
# Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/bigfoot_db"
engine = create_engine(f'postgresql://{connection_string}')
